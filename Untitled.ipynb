# %%
import torch, json, string
import torch.nn as nn
import torch.utils.data as data
import numpy as np
import nltk
import random
import math
import os
from nltk.tokenize import word_tokenize
from torch.autograd import Variable
from tqdm import tqdm_notebook as tqdm
from ipywidgets import IntProgress
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
torch.cuda.device_count()
# Out:
# 8

# %%
NR_GPUS = 8

# %%
torch.cuda.is_available()
# Out:
# True

# %%
print("CUDA device: , CUDA capability:, CUDA device properties: \n")
print(torch.cuda.get_device_name(1), torch.cuda.get_device_capability(1), torch.cuda.get_device_properties(1))
# Out:
# CUDA device: , CUDA capability:, CUDA device properties:
#
# GeForce GTX 1080 Ti (6, 1) _CudaDeviceProperties(name='GeForce GTX 1080 Ti', major=6, minor=1, total_memory=11178MB, multi_processor_count=28)

# %%
device = torch.device("cuda")
device
# Out:
# device(type='cuda')

# %%
fIn = open("/home/alexandru/html/htmlTemplate/inputTest.txt", "r")
files = []
files_sizes = 0
nr = 0
for i in fIn.readlines():
    if "index" in i:
        if nr>10:
            break
        nr +=1
        files_sizes += os.path.getsize("/home/alexandru/html/htmlTemplate/test/"+i[:-1])
        files.append(i[:-1])
fIn.close()

# %%
kB = files_sizes/(1024)
mB = kB/1024
print("kB: ", kB)
print("mB: ", mB)
# Out:
# kB:  1.53515625
# mB:  0.001499176025390625

# %%
PERCENT_OF_TRAINING_DATA = 80
PERCENT_OF_VALIDATION_DATA = 20

# %%
nr_training_samples = math.ceil((len(files) * PERCENT_OF_TRAINING_DATA)/100)
nr_validation_samples = len(files) - nr_training_samples

# %%
nr_training_samples, nr_validation_samples
# Out:
# (9, 2)

# %%
training_html_file_names = files[:nr_training_samples]
validation_html_file_names = files[-nr_validation_samples:]

# %%
len(training_html_file_names)
# Out:
# 9

# %%
len(validation_html_file_names)
# Out:
# 2

# %%
class HTMLDataset(data.Dataset):
    def __init__(self, file_names, vocabulary=None):
        self.file_names = file_names
        
        if not vocabulary:
            self.build_vocabulary()
        else:
            self.vocabulary = vocabulary
    
    def build_vocabulary(self, vocabulary_size=67):
        letters = dict()
        
        for i in range(len(self.file_names)):
            file_name = "/home/alexandru/html/htmlTemplate/test/" + self.file_names[i]


            fIn = open(file_name, "r")

            for line in fIn.readlines():
                line = line.strip()
                line = line.replace('\n', ' ')
                line = line.replace('\t', ' ')
                line = line.replace('  ', ' ')
                line = list(line.lower())

                for character in line:
                    letters[character] = letters.get(character, 0) + 1
            fIn.close()
        
        sorted_letters = sorted(list(letters.items()), key=lambda x: -x[1])
        most_frequent_letters = [w for (w, c) in sorted_letters[:vocabulary_size]]
        letter2id = {w: ( index + 1 ) for (index, w) in enumerate(most_frequent_letters)}
        
        letter2id['[START]'] = len(letter2id) + 1
        letter2id['[UNK]'] = len(letter2id) + 1
        letter2id['[END]'] = len(letter2id) + 1
        
        
        id2letter = {index: letter for (letter, index) in letter2id.items()}
        
        self.vocabulary = {'letter2id':letter2id, 'id2letter':id2letter}        
        
    def html2ids(self, html_file):
        letter2id = self.vocabulary['letter2id']
        
        html_ids = []
        
        file_name = "/home/alexandru/html/htmlTemplate/test/" + html_file
        
        fIn = open(file_name, "r")
        
        for line in fIn.readlines():
            line = line.strip()
            line = line.replace('\n', ' ')
            line = line.replace('\t', ' ')
            line = line.replace('  ', ' ')
            line = list(line.lower())

            for character in line:
                html_ids.append(letter2id.get(character, letter2id['[UNK]']))
        
        fIn.close()
        
        html_ids.insert(0, letter2id['[START]'])
        html_ids.append(letter2id['[END]'])
        
        return torch.LongTensor(html_ids)
    
    
    def ids2letters(self, html_ids):
        id2letter = self.vocabulary['id2letter']
        return "".join([id2letter[i] for i in html_ids])
    
    def __getitem__(self, index):
        html_file = self.file_names[index]
        return self.html2ids(html_file)
    
    def __len__(self):
        return len(self.file_names)

# %%
trainData = HTMLDataset(training_html_file_names)

# %%
validationData = HTMLDataset(validation_html_file_names, vocabulary=trainData.vocabulary)

# %%
id2letter = trainData.vocabulary['id2letter']
trainData.ids2letters(trainData[0].tolist())
# Out:
# '[START]<!doctype html><html><head><title>page title</title></head><body><h1>this is a heading</h1><p>this is a paragraph.</p></body></html>[END]'

# %%
def customBatchBuilder(samples):
    
    seqLengths = [len(seq) for seq in samples]
    maxSeqLength = max(seqLengths)
    sorted_list = sorted(zip(samples, seqLengths), key = lambda x: -x[1])
    
    captionSeqs, seqLengths = zip(*sorted_list)
    
    trainPaddedSeqs = torch.LongTensor(len(seqLengths), maxSeqLength-1) # input and output are shifted from one another
    trainPaddedSeqs.fill_(0)
    targetPaddedSeqs = torch.LongTensor(len(seqLengths), maxSeqLength-1)
    targetPaddedSeqs.fill_(0)
    
    lengths = []
    
    for (i, seq) in enumerate(captionSeqs):
        length = len(seq) - 1
        trainPaddedSeqs[i, :length] = seq[:-1]
        lengths.append(length)
        targetPaddedSeqs[i, :length] = seq[1:]
  
    
    return trainPaddedSeqs, targetPaddedSeqs, lengths

# %%
trainLoader = data.DataLoader(trainData,
                             batch_size = 8,
                             shuffle = True,
                             num_workers = 0,
                             collate_fn = customBatchBuilder)

# %%
validationLoader = data.DataLoader(validationData,
                                  batch_size = 1,
                                  shuffle = False,
                                  num_workers = 0,
                                  collate_fn = customBatchBuilder)

# %%
for i in enumerate(trainLoader):
    print(i)
# Out:
# (0, (tensor([[25,  1, 21,  ..., 16, 11,  2],
#         [25,  1, 21,  ..., 16, 11,  2],
#         [25,  1, 21,  ..., 16, 11,  2],
#         ...,
#         [25,  1, 21,  ..., 16, 11,  2],
#         [25,  1, 21,  ..., 16, 11,  2],
#         [25,  1, 21,  ..., 16, 11,  2]]), tensor([[ 1, 21,  9,  ..., 11,  2, 27],
#         [ 1, 21,  9,  ..., 11,  2, 27],
#         [ 1, 21,  9,  ..., 11,  2, 27],
#         ...,
#         [ 1, 21,  9,  ..., 11,  2, 27],
#         [ 1, 21,  9,  ..., 11,  2, 27],
#         [ 1, 21,  9,  ..., 11,  2, 27]]), [133, 133, 133, 133, 133, 133, 133, 133]))
# (1, (tensor([[25,  1, 21,  9, 14, 22,  3, 15, 10,  6,  7,  4,  3, 16, 11,  2,  1,  4,
#           3, 16, 11,  2,  1,  4,  6,  5,  9,  2,  1,  3,  8,  3, 11,  6,  2, 10,
#           5, 17,  6,  7,  3,  8,  3, 11,  6,  1, 12,  3,  8,  3, 11,  6,  2,  1,
#          12,  4,  6,  5,  9,  2,  1, 18, 14,  9, 15,  2,  1, 10,  2,  3,  4,  8,
#          13,  7,  8, 13,  7,  5,  7, 10,  5, 20,  5, 17, 20,  5, 10,  4,  1, 12,
#          10,  2,  1,  4, 19,  2,  3,  4,  8, 13,  7,  8, 13,  7,  5,  7,  4,  6,
#           5,  9,  8, 23, 17,  1, 12,  4, 19,  2,  1, 12, 18, 14,  9, 15,  2,  1,
#          12,  4,  3, 16, 11,  2]]), tensor([[ 1, 21,  9, 14, 22,  3, 15, 10,  6,  7,  4,  3, 16, 11,  2,  1,  4,  3,
#          16, 11,  2,  1,  4,  6,  5,  9,  2,  1,  3,  8,  3, 11,  6,  2, 10,  5,
#          17,  6,  7,  3,  8,  3, 11,  6,  1, 12,  3,  8,  3, 11,  6,  2,  1, 12,
#           4,  6,  5,  9,  2,  1, 18, 14,  9, 15,  2,  1, 10,  2,  3,  4,  8, 13,
#           7,  8, 13,  7,  5,  7, 10,  5, 20,  5, 17, 20,  5, 10,  4,  1, 12, 10,
#           2,  1,  4, 19,  2,  3,  4,  8, 13,  7,  8, 13,  7,  5,  7,  4,  6,  5,
#           9,  8, 23, 17,  1, 12,  4, 19,  2,  1, 12, 18, 14,  9, 15,  2,  1, 12,
#           4,  3, 16, 11,  2, 27]]), [132]))

# %%
class Model(nn.Module):
    def __init__(self,
                vocabulary_size,
                hidden_size,
                num_layers,
                rnn_dropout,
                embedding_size,
                dropout,
                num_directions):
        super(Model, self).__init__()
        
        self.vocabulary_size = vocabulary_size
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.rnn_dropout = rnn_dropout
        self.dropout = dropout
        self.num_directions = num_directions
        self.embedding_size = embedding_size
        
        
        self.embeddings = nn.Embedding(self.vocabulary_size, self.embedding_size)
        self.rnn = nn.GRU(self.embedding_size,
                          self.hidden_size,
                          num_layers=self.num_layers,
                          bidirectional=True if self.num_directions==2 else False,
                          dropout=self.rnn_dropout,
                          batch_first=True)
        self.linear = nn.Linear(self.hidden_size*self.num_directions, self.vocabulary_size)
        
        
        

        
    def forward(self, paddedSeqs):
        
        batchSequenceLength = paddedSeqs.size(1)
        
        batchSize = paddedSeqs.size(0)
        
        lengths = paddedSeqs.ne(0).sum(dim=1)
                  
        embeddingVectors = self.embeddings(paddedSeqs)
        
        #print("Embedding vector shape is: ", embeddingVectors.shape)
        
        x = torch.nn.utils.rnn.pack_padded_sequence(embeddingVectors, lengths, batch_first=True)
        
        self.rnn.flatten_parameters()
        
        #print("After pack padded seq, input shape is: ", x.shape)
        hidden = self.init_hidden(paddedSeqs)
        x,hid = self.rnn(x, hidden)
        
        output, _ = torch.nn.utils.rnn.pad_packed_sequence(x, batch_first=True, padding_value=0, total_length=batchSequenceLength)
        
        
        #print("Output after pad packed sequence: ", output.shape)
        
        predictions = self.linear(output)
        
        #print("Predictions after the linear layer have shape: ", predictions.shape)
        
        #return predictions.view(batchSize, self.vocabulary_size, batchSequenceLength), hid
        
        return predictions.view(batchSize, self.vocabulary_size, batchSequenceLength), hid
                
        #return predictions, hidden
        
        #return predictions.view(-1, self.vocabularySize), hidden
    
        #return predictions, hidden
    
    
    def init_hidden(self, paddedSeqs):
        #nr = 3
        #if paddedSeqs.size(0) == 12:
        #    nr=2
        #elif paddedSeqs.size(0)<12:
        #    nr=1
        #Hidden (num_layers * num_directions, batch_size, hidden_size
        hidden = Variable(torch.zeros(self.num_layers*self.num_directions,
                                    paddedSeqs.size(0),#2, if paddedSeqs.size(0)==NR_GPUS else int(paddedSeqs.size(0)%NR_GPUS),
                                    self.hidden_size).to(device))
        return hidden

# %%
class ModelOne(Model) :
    def __init__(self,
                vocabulary_size,
                hidden_size,
                num_layers,
                rnn_dropout,
                embedding_size,
                dropout,
                num_directions):
        super(Model, self).__init__()
        
        self.vocabulary_size = vocabulary_size
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.rnn_dropout = rnn_dropout
        self.dropout = dropout
        self.num_directions = num_directions
        self.embedding_size = embedding_size
        
        
        self.embeddings = nn.Embedding(self.vocabulary_size, self.embedding_size)
        self.rnn = nn.GRU(self.embedding_size,
                          self.hidden_size,
                          num_layers=self.num_layers,
                          bidirectional=True if self.num_directions==2 else False,
                          dropout=self.rnn_dropout,
                          batch_first=True)
        self.linear = nn.Linear(self.hidden_size*self.num_directions, self.vocabulary_size)
        
        
        

        
    def forward(self, paddedSeqs, hidden):
        
        batchSequenceLength = paddedSeqs.size(1)
        
        batchSize = paddedSeqs.size(0)
        
        lengths = paddedSeqs.ne(0).sum(dim=1)
                  
        embeddingVectors = self.embeddings(paddedSeqs)
        
        #print("Embedding vector shape is: ", embeddingVectors.shape)
        
        x = torch.nn.utils.rnn.pack_padded_sequence(embeddingVectors, lengths, batch_first=True)
        
        self.rnn.flatten_parameters()
        
        #print("After pack padded seq, input shape is: ", x.shape)
        #hidden = self.init_hidden(paddedSeqs)
        x,hid = self.rnn(x, hidden)
        
        output, _ = torch.nn.utils.rnn.pad_packed_sequence(x, batch_first=True, padding_value=0, total_length=batchSequenceLength)
        
        
        #print("Output after pad packed sequence: ", output.shape)
        
        predictions = self.linear(output)
        
        #print("Predictions after the linear layer have shape: ", predictions.shape)
        
        #return predictions.view(batchSize, self.vocabulary_size, batchSequenceLength), hid
        
        return predictions.view(batchSize, self.vocabulary_size, batchSequenceLength), hid
                
        #return predictions, hidden
        
        #return predictions.view(-1, self.vocabularySize), hidden
    
        #return predictions, hidden
    
    
    def init_hidden(self, paddedSeqs):
        #nr = 3
        #if paddedSeqs.size(0) == 12:
        #    nr=2
        #elif paddedSeqs.size(0)<12:
        #    nr=1
        #Hidden (num_layers * num_directions, batch_size, hidden_size
        hidden = Variable(torch.zeros(self.num_layers*self.num_directions,
                                    1,#paddedSeqs.size(0),#2, if paddedSeqs.size(0)==NR_GPUS else int(paddedSeqs.size(0)%NR_GPUS),
                                    self.hidden_size).to(device))
        return hidden

# %%
a = torch.Tensor([4])
a%8
# Out:
# tensor([4.])

# %%
vocabularySize = len(trainData.vocabulary['letter2id'])+1
model = Model(vocabulary_size=vocabularySize,
             hidden_size=100,
             embedding_size=50,
             num_layers=3,
             rnn_dropout=0.0,
             dropout=0,
             num_directions=2).to(device)
model = nn.DataParallel(model)

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
print(count_parameters(model))
# Out:
# 460628

# %%
criterion = nn.CrossEntropyLoss(ignore_index=0)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
train_losses = []
train_accuracy = []
valid_losses = []
valid_accuracy = []
train_epochs = []
validation_epochs = []

# %%
def accuracy(prediction, label, mask):
    correct = 0
    for (pred, target, msk) in zip(prediction, label, mask):
        correct += pred[0][0:msk].eq(target[0][0:msk]).to(device).sum()
    return correct

# %%
def plot_results(plot_title, folder_name, x_label, y_label, x_data, y_data):
    plt.title(plot_title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    
    plt.plot(x_data, y_data, color = "r")
    plt.grid()
    plt.savefig("/home/alexandru/workspace/" + folder_name + "/" + plot_title + ".png", bbox_inches = "tight")

# %%
def repackage_hidden(h):
    """Wraps hidden states in new Tensors, to detach them from their history."""
    if isinstance(h, torch.Tensor):
        return h.detach()
    else:
        return tuple(repackage_hidden(v) for v in h)

# %%
def train(epoch):
    model.train()
    
    correct = 0
    counter = 0
    cummulative_loss = 0
    total_loss = 0
    total_accuracy = 0
    
    for index, (input, target, lengths) in enumerate(trainLoader):
        
        input = Variable(input.to(device))
        target = Variable(target.to(device))
        
        #hidden = model.module.init_hidden(input)
        
        lengths = Variable(torch.tensor(lengths).to(device))
        
        #hidden = repackage_hidden(hidden)
             
        
        output, _ = model(input)
        
        optimizer.zero_grad()        
        
        loss = criterion(output, target)
        
        cummulative_loss += loss.item()
        
        pred = output.data.max(1, keepdim=True)[1]
        
        correct += accuracy(pred, target.data.view_as(pred), lengths)
        
        total_loss = cummulative_loss/(index+1)
        
        counter += output.size(0) * output.size(2)
        
        total_accuracy = 100. * correct/counter
        
        train_losses.append(total_loss)
        train_accuracy.append(total_accuracy)
        train_epochs.append(epoch)
        
        loss.backward()
        
        optimizer.step()
        
        
    print("[Epoch: %d][Batch:%d][Training Accuracy: %g %%][Loss: %g]"%(epoch,
                                                            index+1,
                                                            total_accuracy,
                                                            cummulative_loss/(index+1)))

# %%
def evaluate(epoch):
    model.eval()
    correct = 0
    test_loss = 0
    total_loss = 0
    total_accuracy = 0
    counter = 0
    with torch.no_grad():
        for index, (input, target, lengths) in enumerate(validationLoader):
            
            input = Variable(input.to(device))
            target = Variable(target.to(device))
            lengths = Variable(torch.tensor(lengths).to(device))
            #hidden = model.module.init_hidden(input)
                        
            output, _ = model(input)
            
            loss = criterion(output, target)
            
            test_loss += loss.item()
            
            pred = output.data.max(1, keepdim = True)[1]
            
            correct += accuracy(pred, target.data.view_as(pred), lengths)
            
            counter += output.size(0) * output.size(2)
            
            total_loss = test_loss/(index+1)
            
            total_accuracy = 100. * correct/counter
            
            valid_losses.append(total_loss)
            
            valid_accuracy.append(total_accuracy)
            
            validation_epochs.append(epoch)
            
        print("\n[Epoch: %d] Validation accuracy: %g %%, Validation loss: %g "%(epoch, total_accuracy, total_loss))

# %%
for epoch in range(1000):
    train(epoch)
    evaluate(epoch)
    #name = "/home/alexandru/html/model/html/IndexTemplateHiddenGpu8Layer3Hidden500Embed50Dropout1Epoch" + str(epoch)
    #torch.save(model.module.state_dict(), name)
# Out:
# [Epoch: 0][Batch:2][Training Accuracy: 2 %][Loss: 3.31049]
#
# [Epoch: 0] Validation accuracy: 19 %, Validation loss: 3.21676
# [Epoch: 1][Batch:2][Training Accuracy: 19 %][Loss: 3.18871]
#
# [Epoch: 1] Validation accuracy: 21 %, Validation loss: 3.09214
# [Epoch: 2][Batch:2][Training Accuracy: 20 %][Loss: 3.06809]
#
# [Epoch: 2] Validation accuracy: 21 %, Validation loss: 2.97131
# [Epoch: 3][Batch:2][Training Accuracy: 20 %][Loss: 2.953]
#
# [Epoch: 3] Validation accuracy: 21 %, Validation loss: 2.84647
# [Epoch: 4][Batch:2][Training Accuracy: 20 %][Loss: 2.82727]
#
# [Epoch: 4] Validation accuracy: 21 %, Validation loss: 2.70004
# [Epoch: 5][Batch:2][Training Accuracy: 20 %][Loss: 2.68764]
#
# [Epoch: 5] Validation accuracy: 24 %, Validation loss: 2.57101
# [Epoch: 6][Batch:2][Training Accuracy: 22 %][Loss: 2.57276]
#
# [Epoch: 6] Validation accuracy: 25 %, Validation loss: 2.46699
# [Epoch: 7][Batch:2][Training Accuracy: 24 %][Loss: 2.47099]
#
# [Epoch: 7] Validation accuracy: 30 %, Validation loss: 2.3439
# [Epoch: 8][Batch:2][Training Accuracy: 28 %][Loss: 2.34973]
#
# [Epoch: 8] Validation accuracy: 33 %, Validation loss: 2.21338
# [Epoch: 9][Batch:2][Training Accuracy: 31 %][Loss: 2.2287]
#
# [Epoch: 9] Validation accuracy: 33 %, Validation loss: 2.09636
# [Epoch: 10][Batch:2][Training Accuracy: 32 %][Loss: 2.11825]
#
# [Epoch: 10] Validation accuracy: 36 %, Validation loss: 1.98285
# [Epoch: 11][Batch:2][Training Accuracy: 34 %][Loss: 2.01016]
#
# [Epoch: 11] Validation accuracy: 39 %, Validation loss: 1.87493
# [Epoch: 12][Batch:2][Training Accuracy: 38 %][Loss: 1.90809]
#
# [Epoch: 12] Validation accuracy: 45 %, Validation loss: 1.77023
# [Epoch: 13][Batch:2][Training Accuracy: 43 %][Loss: 1.80646]
#
# [Epoch: 13] Validation accuracy: 47 %, Validation loss: 1.65887
# [Epoch: 14][Batch:2][Training Accuracy: 45 %][Loss: 1.70055]
#
# [Epoch: 14] Validation accuracy: 51 %, Validation loss: 1.55031
# [Epoch: 15][Batch:2][Training Accuracy: 49 %][Loss: 1.59934]
#
# [Epoch: 15] Validation accuracy: 55 %, Validation loss: 1.44481
# [Epoch: 16][Batch:2][Training Accuracy: 52 %][Loss: 1.49906]
#
# [Epoch: 16] Validation accuracy: 61 %, Validation loss: 1.33861
# [Epoch: 17][Batch:2][Training Accuracy: 59 %][Loss: 1.39918]
#
# [Epoch: 17] Validation accuracy: 67 %, Validation loss: 1.23581
# [Epoch: 18][Batch:2][Training Accuracy: 64 %][Loss: 1.30175]
#
# [Epoch: 18] Validation accuracy: 75 %, Validation loss: 1.13436
# [Epoch: 19][Batch:2][Training Accuracy: 72 %][Loss: 1.20645]
#
# [Epoch: 19] Validation accuracy: 81 %, Validation loss: 1.03708
# [Epoch: 20][Batch:2][Training Accuracy: 77 %][Loss: 1.11456]
#
# [Epoch: 20] Validation accuracy: 84 %, Validation loss: 0.941648
# [Epoch: 21][Batch:2][Training Accuracy: 79 %][Loss: 1.02426]
#
# [Epoch: 21] Validation accuracy: 87 %, Validation loss: 0.849438
# [Epoch: 22][Batch:2][Training Accuracy: 83 %][Loss: 0.937809]
#
# [Epoch: 22] Validation accuracy: 92 %, Validation loss: 0.762437
# [Epoch: 23][Batch:2][Training Accuracy: 87 %][Loss: 0.856585]
#
# [Epoch: 23] Validation accuracy: 95 %, Validation loss: 0.680522
# [Epoch: 24][Batch:2][Training Accuracy: 90 %][Loss: 0.780054]
#
# [Epoch: 24] Validation accuracy: 97 %, Validation loss: 0.603744
# [Epoch: 25][Batch:2][Training Accuracy: 91 %][Loss: 0.708504]
#
# [Epoch: 25] Validation accuracy: 97 %, Validation loss: 0.532516
# [Epoch: 26][Batch:2][Training Accuracy: 91 %][Loss: 0.642708]
#
# [Epoch: 26] Validation accuracy: 98 %, Validation loss: 0.467762
# [Epoch: 27][Batch:2][Training Accuracy: 92 %][Loss: 0.58311]
#
# [Epoch: 27] Validation accuracy: 98 %, Validation loss: 0.409636
# [Epoch: 28][Batch:2][Training Accuracy: 92 %][Loss: 0.529726]
#
# [Epoch: 28] Validation accuracy: 100 %, Validation loss: 0.358009
# [Epoch: 29][Batch:2][Training Accuracy: 94 %][Loss: 0.48244]
#
# [Epoch: 29] Validation accuracy: 100 %, Validation loss: 0.312748
# [Epoch: 30][Batch:2][Training Accuracy: 89 %][Loss: 2.7011]
#
# [Epoch: 30] Validation accuracy: 99 %, Validation loss: 0.296594
# [Epoch: 31][Batch:2][Training Accuracy: 93 %][Loss: 0.438715]
#
# [Epoch: 31] Validation accuracy: 100 %, Validation loss: 0.287684
# [Epoch: 32][Batch:2][Training Accuracy: 94 %][Loss: 0.418503]
#
# [Epoch: 32] Validation accuracy: 100 %, Validation loss: 0.270781
# [Epoch: 33][Batch:2][Training Accuracy: 94 %][Loss: 0.399748]
#
# [Epoch: 33] Validation accuracy: 100 %, Validation loss: 0.24171
# [Epoch: 34][Batch:2][Training Accuracy: 93 %][Loss: 0.370943]
#
# [Epoch: 34] Validation accuracy: 100 %, Validation loss: 0.217182
# [Epoch: 35][Batch:2][Training Accuracy: 94 %][Loss: 0.350126]
#
# [Epoch: 35] Validation accuracy: 100 %, Validation loss: 0.198723
# [Epoch: 36][Batch:2][Training Accuracy: 94 %][Loss: 0.331108]
#
# [Epoch: 36] Validation accuracy: 100 %, Validation loss: 0.178608
# [Epoch: 37][Batch:2][Training Accuracy: 94 %][Loss: 0.312499]
#
# [Epoch: 37] Validation accuracy: 100 %, Validation loss: 0.163826
# [Epoch: 38][Batch:2][Training Accuracy: 94 %][Loss: 0.29771]
#
# [Epoch: 38] Validation accuracy: 100 %, Validation loss: 0.148797
# [Epoch: 39][Batch:2][Training Accuracy: 94 %][Loss: 0.282535]
#
# [Epoch: 39] Validation accuracy: 100 %, Validation loss: 0.134794
# [Epoch: 40][Batch:2][Training Accuracy: 94 %][Loss: 0.26943]
#
# [Epoch: 40] Validation accuracy: 100 %, Validation loss: 0.124227
# [Epoch: 41][Batch:2][Training Accuracy: 90 %][Loss: 2.51246]
#
# [Epoch: 41] Validation accuracy: 100 %, Validation loss: 0.122776
# [Epoch: 42][Batch:2][Training Accuracy: 94 %][Loss: 0.26188]
#
# [Epoch: 42] Validation accuracy: 100 %, Validation loss: 0.132176
# [Epoch: 43][Batch:2][Training Accuracy: 94 %][Loss: 0.263419]
#
# [Epoch: 43] Validation accuracy: 100 %, Validation loss: 0.127956
# [Epoch: 44][Batch:2][Training Accuracy: 94 %][Loss: 0.255913]
#
# [Epoch: 44] Validation accuracy: 100 %, Validation loss: 0.124557
# [Epoch: 45][Batch:2][Training Accuracy: 94 %][Loss: 0.250314]
#
# [Epoch: 45] Validation accuracy: 100 %, Validation loss: 0.117789
# [Epoch: 46][Batch:2][Training Accuracy: 94 %][Loss: 0.241712]
#
# [Epoch: 46] Validation accuracy: 100 %, Validation loss: 0.109216
# [Epoch: 47][Batch:2][Training Accuracy: 94 %][Loss: 0.232536]
#
# [Epoch: 47] Validation accuracy: 100 %, Validation loss: 0.102822
# [Epoch: 48][Batch:2][Training Accuracy: 94 %][Loss: 0.225638]
#
# [Epoch: 48] Validation accuracy: 100 %, Validation loss: 0.0978957
# [Epoch: 49][Batch:2][Training Accuracy: 94 %][Loss: 0.219676]
#
# [Epoch: 49] Validation accuracy: 100 %, Validation loss: 0.0929423
# [Epoch: 50][Batch:2][Training Accuracy: 94 %][Loss: 0.21317]
#
# [Epoch: 50] Validation accuracy: 100 %, Validation loss: 0.087852
# [Epoch: 51][Batch:2][Training Accuracy: 94 %][Loss: 0.206483]
#
# [Epoch: 51] Validation accuracy: 100 %, Validation loss: 0.0833114
# [Epoch: 52][Batch:2][Training Accuracy: 94 %][Loss: 0.200472]
#
# [Epoch: 52] Validation accuracy: 100 %, Validation loss: 0.0793766
# [Epoch: 53][Batch:2][Training Accuracy: 94 %][Loss: 0.194999]
#
# [Epoch: 53] Validation accuracy: 100 %, Validation loss: 0.0757497
# [Epoch: 54][Batch:2][Training Accuracy: 94 %][Loss: 0.189739]
#
# [Epoch: 54] Validation accuracy: 100 %, Validation loss: 0.0724334
# [Epoch: 55][Batch:2][Training Accuracy: 94 %][Loss: 0.184757]
#
# [Epoch: 55] Validation accuracy: 100 %, Validation loss: 0.0695577
# [Epoch: 56][Batch:2][Training Accuracy: 95 %][Loss: 0.180218]
#
# [Epoch: 56] Validation accuracy: 100 %, Validation loss: 0.0670976
# [Epoch: 57][Batch:2][Training Accuracy: 95 %][Loss: 0.176058]
#
# [Epoch: 57] Validation accuracy: 100 %, Validation loss: 0.0648233
# [Epoch: 58][Batch:2][Training Accuracy: 95 %][Loss: 0.172027]
#
# [Epoch: 58] Validation accuracy: 100 %, Validation loss: 0.0625935
# [Epoch: 59][Batch:2][Training Accuracy: 95 %][Loss: 0.168062]
#
# [Epoch: 59] Validation accuracy: 100 %, Validation loss: 0.0605617
# [Epoch: 60][Batch:2][Training Accuracy: 95 %][Loss: 0.164333]
#
# [Epoch: 60] Validation accuracy: 100 %, Validation loss: 0.0588338
# [Epoch: 61][Batch:2][Training Accuracy: 95 %][Loss: 0.160869]
#
# [Epoch: 61] Validation accuracy: 100 %, Validation loss: 0.057316
# [Epoch: 62][Batch:2][Training Accuracy: 95 %][Loss: 0.157532]
#
# [Epoch: 62] Validation accuracy: 100 %, Validation loss: 0.0559192
# [Epoch: 63][Batch:2][Training Accuracy: 95 %][Loss: 0.154261]
#
# [Epoch: 63] Validation accuracy: 100 %, Validation loss: 0.0546416
# [Epoch: 64][Batch:2][Training Accuracy: 95 %][Loss: 0.151105]
#
# [Epoch: 64] Validation accuracy: 100 %, Validation loss: 0.053482
# [Epoch: 65][Batch:2][Training Accuracy: 89 %][Loss: 2.47216]
#
# [Epoch: 65] Validation accuracy: 100 %, Validation loss: 0.056062
# [Epoch: 66][Batch:2][Training Accuracy: 95 %][Loss: 0.152875]
#
# [Epoch: 66] Validation accuracy: 100 %, Validation loss: 0.0686578
# [Epoch: 67][Batch:2][Training Accuracy: 95 %][Loss: 0.161501]
#
# [Epoch: 67] Validation accuracy: 100 %, Validation loss: 0.0695363
# [Epoch: 68][Batch:2][Training Accuracy: 95 %][Loss: 0.159276]
#
# [Epoch: 68] Validation accuracy: 100 %, Validation loss: 0.0714405
# [Epoch: 69][Batch:2][Training Accuracy: 95 %][Loss: 0.159068]
#
# [Epoch: 69] Validation accuracy: 100 %, Validation loss: 0.0708012
# [Epoch: 70][Batch:2][Training Accuracy: 95 %][Loss: 0.157169]
#
# [Epoch: 70] Validation accuracy: 100 %, Validation loss: 0.0677437
# [Epoch: 71][Batch:2][Training Accuracy: 95 %][Loss: 0.153504]
#
# [Epoch: 71] Validation accuracy: 100 %, Validation loss: 0.0644273
# [Epoch: 72][Batch:2][Training Accuracy: 95 %][Loss: 0.14987]
#
# [Epoch: 72] Validation accuracy: 100 %, Validation loss: 0.0608037
# [Epoch: 73][Batch:2][Training Accuracy: 95 %][Loss: 0.145812]
#
# [Epoch: 73] Validation accuracy: 100 %, Validation loss: 0.0571705
# [Epoch: 74][Batch:2][Training Accuracy: 95 %][Loss: 0.141654]
#
# [Epoch: 74] Validation accuracy: 100 %, Validation loss: 0.0546725
# [Epoch: 75][Batch:2][Training Accuracy: 95 %][Loss: 0.138537]
#
# [Epoch: 75] Validation accuracy: 100 %, Validation loss: 0.0531288
# [Epoch: 76][Batch:2][Training Accuracy: 95 %][Loss: 0.135971]
#
# [Epoch: 76] Validation accuracy: 100 %, Validation loss: 0.0513469
# [Epoch: 77][Batch:2][Training Accuracy: 95 %][Loss: 0.13287]
#
# [Epoch: 77] Validation accuracy: 100 %, Validation loss: 0.0492037
# [Epoch: 78][Batch:2][Training Accuracy: 95 %][Loss: 0.129515]
#
# [Epoch: 78] Validation accuracy: 100 %, Validation loss: 0.047486
# [Epoch: 79][Batch:2][Training Accuracy: 95 %][Loss: 0.126676]
#
# [Epoch: 79] Validation accuracy: 100 %, Validation loss: 0.0462645
# [Epoch: 80][Batch:2][Training Accuracy: 95 %][Loss: 0.124227]
#
# [Epoch: 80] Validation accuracy: 100 %, Validation loss: 0.0451835
# [Epoch: 81][Batch:2][Training Accuracy: 95 %][Loss: 0.121737]
#
# [Epoch: 81] Validation accuracy: 100 %, Validation loss: 0.0441446
# [Epoch: 82][Batch:2][Training Accuracy: 95 %][Loss: 0.1192]
#
# [Epoch: 82] Validation accuracy: 100 %, Validation loss: 0.0432521
# [Epoch: 83][Batch:2][Training Accuracy: 89 %][Loss: 2.20661]
#
# [Epoch: 83] Validation accuracy: 100 %, Validation loss: 0.0443861
# [Epoch: 84][Batch:2][Training Accuracy: 90 %][Loss: 2.05731]
#
# [Epoch: 84] Validation accuracy: 100 %, Validation loss: 0.057102
# [Epoch: 85][Batch:2][Training Accuracy: 96 %][Loss: 0.135724]
#
# [Epoch: 85] Validation accuracy: 100 %, Validation loss: 0.082629
# [Epoch: 86][Batch:2][Training Accuracy: 95 %][Loss: 0.156812]
#
# [Epoch: 86] Validation accuracy: 100 %, Validation loss: 0.0885846
# [Epoch: 87][Batch:2][Training Accuracy: 95 %][Loss: 0.159297]
#
# [Epoch: 87] Validation accuracy: 100 %, Validation loss: 0.0854132
# [Epoch: 88][Batch:2][Training Accuracy: 95 %][Loss: 0.157365]
#
# [Epoch: 88] Validation accuracy: 100 %, Validation loss: 0.0824126
# [Epoch: 89][Batch:2][Training Accuracy: 95 %][Loss: 0.156089]
#
# [Epoch: 89] Validation accuracy: 100 %, Validation loss: 0.0777384
# [Epoch: 90][Batch:2][Training Accuracy: 95 %][Loss: 0.152667]
#
# [Epoch: 90] Validation accuracy: 100 %, Validation loss: 0.0711125
# [Epoch: 91][Batch:2][Training Accuracy: 95 %][Loss: 0.146922]
#
# [Epoch: 91] Validation accuracy: 100 %, Validation loss: 0.06463
# [Epoch: 92][Batch:2][Training Accuracy: 95 %][Loss: 0.141099]
#
# [Epoch: 92] Validation accuracy: 100 %, Validation loss: 0.0594534
# [Epoch: 93][Batch:2][Training Accuracy: 95 %][Loss: 0.136207]
#
# [Epoch: 93] Validation accuracy: 100 %, Validation loss: 0.0554483
# [Epoch: 94][Batch:2][Training Accuracy: 95 %][Loss: 0.132012]
#
# [Epoch: 94] Validation accuracy: 100 %, Validation loss: 0.0520952
# [Epoch: 95][Batch:2][Training Accuracy: 95 %][Loss: 0.127963]
#
# [Epoch: 95] Validation accuracy: 100 %, Validation loss: 0.0491268
# [Epoch: 96][Batch:2][Training Accuracy: 96 %][Loss: 0.123854]
#
# [Epoch: 96] Validation accuracy: 100 %, Validation loss: 0.0465912
# [Epoch: 97][Batch:2][Training Accuracy: 91 %][Loss: 1.6218]
#
# [Epoch: 97] Validation accuracy: 100 %, Validation loss: 0.0466116
# [Epoch: 98][Batch:2][Training Accuracy: 96 %][Loss: 0.120553]
#
# [Epoch: 98] Validation accuracy: 100 %, Validation loss: 0.0506299
# [Epoch: 99][Batch:2][Training Accuracy: 96 %][Loss: 0.123092]
#
# [Epoch: 99] Validation accuracy: 100 %, Validation loss: 0.0540717
# [Epoch: 100][Batch:2][Training Accuracy: 96 %][Loss: 0.124848]
#
# [Epoch: 100] Validation accuracy: 100 %, Validation loss: 0.0554831
# [Epoch: 101][Batch:2][Training Accuracy: 96 %][Loss: 0.124606]
#
# [Epoch: 101] Validation accuracy: 100 %, Validation loss: 0.0547361
# [Epoch: 102][Batch:2][Training Accuracy: 96 %][Loss: 0.122555]
#
# [Epoch: 102] Validation accuracy: 100 %, Validation loss: 0.0527274
# [Epoch: 103][Batch:2][Training Accuracy: 96 %][Loss: 0.119642]
#
# [Epoch: 103] Validation accuracy: 100 %, Validation loss: 0.0503629
# [Epoch: 104][Batch:2][Training Accuracy: 96 %][Loss: 0.116623]
#
# [Epoch: 104] Validation accuracy: 100 %, Validation loss: 0.048081
# [Epoch: 105][Batch:2][Training Accuracy: 96 %][Loss: 0.113773]
#
# [Epoch: 105] Validation accuracy: 100 %, Validation loss: 0.0459662
# [Epoch: 106][Batch:2][Training Accuracy: 96 %][Loss: 0.111063]
#
# [Epoch: 106] Validation accuracy: 100 %, Validation loss: 0.0439869
# [Epoch: 107][Batch:2][Training Accuracy: 96 %][Loss: 0.108405]
#
# [Epoch: 107] Validation accuracy: 100 %, Validation loss: 0.0421357
# [Epoch: 108][Batch:2][Training Accuracy: 96 %][Loss: 0.105774]
#
# [Epoch: 108] Validation accuracy: 100 %, Validation loss: 0.0404507
# [Epoch: 109][Batch:2][Training Accuracy: 96 %][Loss: 0.103217]
#
# [Epoch: 109] Validation accuracy: 100 %, Validation loss: 0.0389766
# [Epoch: 110][Batch:2][Training Accuracy: 96 %][Loss: 0.100788]
#
# [Epoch: 110] Validation accuracy: 100 %, Validation loss: 0.0377275
# [Epoch: 111][Batch:2][Training Accuracy: 96 %][Loss: 0.0985132]
#
# [Epoch: 111] Validation accuracy: 100 %, Validation loss: 0.0366831
# [Epoch: 112][Batch:2][Training Accuracy: 96 %][Loss: 0.0963839]
#
# [Epoch: 112] Validation accuracy: 100 %, Validation loss: 0.0358043
# [Epoch: 113][Batch:2][Training Accuracy: 96 %][Loss: 0.0943798]
#
# [Epoch: 113] Validation accuracy: 100 %, Validation loss: 0.0350479
# [Epoch: 114][Batch:2][Training Accuracy: 96 %][Loss: 0.0924842]
#
# [Epoch: 114] Validation accuracy: 100 %, Validation loss: 0.0343749
# [Epoch: 115][Batch:2][Training Accuracy: 96 %][Loss: 0.0906872]
#
# [Epoch: 115] Validation accuracy: 100 %, Validation loss: 0.0337558
# [Epoch: 116][Batch:2][Training Accuracy: 96 %][Loss: 0.0889839]
#
# [Epoch: 116] Validation accuracy: 100 %, Validation loss: 0.0331721
# [Epoch: 117][Batch:2][Training Accuracy: 96 %][Loss: 0.0873724]
#
# [Epoch: 117] Validation accuracy: 100 %, Validation loss: 0.0326138
# [Epoch: 118][Batch:2][Training Accuracy: 96 %][Loss: 0.0858508]
#
# [Epoch: 118] Validation accuracy: 100 %, Validation loss: 0.0320759
# [Epoch: 119][Batch:2][Training Accuracy: 96 %][Loss: 0.0844135]
#
# [Epoch: 119] Validation accuracy: 100 %, Validation loss: 0.0315545
# [Epoch: 120][Batch:2][Training Accuracy: 96 %][Loss: 0.0830515]
#
# [Epoch: 120] Validation accuracy: 100 %, Validation loss: 0.0310456
# [Epoch: 121][Batch:2][Training Accuracy: 96 %][Loss: 0.0817537]
#
# [Epoch: 121] Validation accuracy: 100 %, Validation loss: 0.0305468
# [Epoch: 122][Batch:2][Training Accuracy: 96 %][Loss: 0.0805112]
#
# [Epoch: 122] Validation accuracy: 100 %, Validation loss: 0.0300575
# [Epoch: 123][Batch:2][Training Accuracy: 97 %][Loss: 0.0793178]
#
# [Epoch: 123] Validation accuracy: 100 %, Validation loss: 0.029579
# [Epoch: 124][Batch:2][Training Accuracy: 97 %][Loss: 0.0781696]
#
# [Epoch: 124] Validation accuracy: 100 %, Validation loss: 0.0291125
# [Epoch: 125][Batch:2][Training Accuracy: 97 %][Loss: 0.077063]
#
# [Epoch: 125] Validation accuracy: 100 %, Validation loss: 0.0286597
# [Epoch: 126][Batch:2][Training Accuracy: 97 %][Loss: 0.0759946]
#
# [Epoch: 126] Validation accuracy: 100 %, Validation loss: 0.0282216
# [Epoch: 127][Batch:2][Training Accuracy: 97 %][Loss: 0.0749612]
#
# [Epoch: 127] Validation accuracy: 100 %, Validation loss: 0.0277989
# [Epoch: 128][Batch:2][Training Accuracy: 97 %][Loss: 0.0739598]
#
# [Epoch: 128] Validation accuracy: 100 %, Validation loss: 0.0273919
# [Epoch: 129][Batch:2][Training Accuracy: 97 %][Loss: 0.0729876]
#
# [Epoch: 129] Validation accuracy: 100 %, Validation loss: 0.0270009
# [Epoch: 130][Batch:2][Training Accuracy: 97 %][Loss: 0.0720426]
#
# [Epoch: 130] Validation accuracy: 100 %, Validation loss: 0.0266259
# [Epoch: 131][Batch:2][Training Accuracy: 97 %][Loss: 0.0711235]
#
# [Epoch: 131] Validation accuracy: 100 %, Validation loss: 0.0262668
# [Epoch: 132][Batch:2][Training Accuracy: 97 %][Loss: 0.0702298]
#
# [Epoch: 132] Validation accuracy: 100 %, Validation loss: 0.0259231
# [Epoch: 133][Batch:2][Training Accuracy: 97 %][Loss: 0.0693613]
#
# [Epoch: 133] Validation accuracy: 100 %, Validation loss: 0.0255937
# [Epoch: 134][Batch:2][Training Accuracy: 97 %][Loss: 0.0685168]
#
# [Epoch: 134] Validation accuracy: 100 %, Validation loss: 0.0252769
# [Epoch: 135][Batch:2][Training Accuracy: 97 %][Loss: 0.067695]
#
# [Epoch: 135] Validation accuracy: 100 %, Validation loss: 0.0249709
# [Epoch: 136][Batch:2][Training Accuracy: 97 %][Loss: 0.0668935]
#
# [Epoch: 136] Validation accuracy: 100 %, Validation loss: 0.0246739
# [Epoch: 137][Batch:2][Training Accuracy: 97 %][Loss: 0.0661098]
#
# [Epoch: 137] Validation accuracy: 100 %, Validation loss: 0.0243843
# [Epoch: 138][Batch:2][Training Accuracy: 97 %][Loss: 0.065341]
#
# [Epoch: 138] Validation accuracy: 100 %, Validation loss: 0.0241012
# [Epoch: 139][Batch:2][Training Accuracy: 91 %][Loss: 1.95119]
#
# [Epoch: 139] Validation accuracy: 100 %, Validation loss: 0.0246288
# [Epoch: 140][Batch:2][Training Accuracy: 97 %][Loss: 0.0661996]
#
# [Epoch: 140] Validation accuracy: 100 %, Validation loss: 0.0280365
# [Epoch: 141][Batch:2][Training Accuracy: 97 %][Loss: 0.0710424]
#
# [Epoch: 141] Validation accuracy: 100 %, Validation loss: 0.0311547
# [Epoch: 142][Batch:2][Training Accuracy: 97 %][Loss: 0.0748345]
#
# [Epoch: 142] Validation accuracy: 100 %, Validation loss: 0.0325703
# [Epoch: 143][Batch:2][Training Accuracy: 97 %][Loss: 0.0760028]
#
# [Epoch: 143] Validation accuracy: 100 %, Validation loss: 0.0328192
# [Epoch: 144][Batch:2][Training Accuracy: 97 %][Loss: 0.0760831]
#
# [Epoch: 144] Validation accuracy: 100 %, Validation loss: 0.0321179
# [Epoch: 145][Batch:2][Training Accuracy: 91 %][Loss: 1.49403]
#
# [Epoch: 145] Validation accuracy: 100 %, Validation loss: 0.033265
# [Epoch: 146][Batch:2][Training Accuracy: 97 %][Loss: 0.0791505]
#
# [Epoch: 146] Validation accuracy: 100 %, Validation loss: 0.0375956
# [Epoch: 147][Batch:2][Training Accuracy: 96 %][Loss: 0.0846988]
#
# [Epoch: 147] Validation accuracy: 100 %, Validation loss: 0.0407646
# [Epoch: 148][Batch:2][Training Accuracy: 96 %][Loss: 0.0889084]
#
# [Epoch: 148] Validation accuracy: 100 %, Validation loss: 0.0418085
# [Epoch: 149][Batch:2][Training Accuracy: 96 %][Loss: 0.0904497]
#
# [Epoch: 149] Validation accuracy: 100 %, Validation loss: 0.040933
# [Epoch: 150][Batch:2][Training Accuracy: 96 %][Loss: 0.0895971]
#
# [Epoch: 150] Validation accuracy: 100 %, Validation loss: 0.0390999
# [Epoch: 151][Batch:2][Training Accuracy: 96 %][Loss: 0.0876302]
#
# [Epoch: 151] Validation accuracy: 100 %, Validation loss: 0.0369523
# [Epoch: 152][Batch:2][Training Accuracy: 97 %][Loss: 0.0852488]
#
# [Epoch: 152] Validation accuracy: 100 %, Validation loss: 0.034795
# [Epoch: 153][Batch:2][Training Accuracy: 97 %][Loss: 0.0826952]
#
# [Epoch: 153] Validation accuracy: 100 %, Validation loss: 0.0328127
# [Epoch: 154][Batch:2][Training Accuracy: 92 %][Loss: 1.19016]
#
# [Epoch: 154] Validation accuracy: 100 %, Validation loss: 0.033617
# [Epoch: 155][Batch:2][Training Accuracy: 97 %][Loss: 0.084127]
#
# [Epoch: 155] Validation accuracy: 100 %, Validation loss: 0.0407993
# [Epoch: 156][Batch:2][Training Accuracy: 96 %][Loss: 0.0934823]
#
# [Epoch: 156] Validation accuracy: 100 %, Validation loss: 0.04273
# [Epoch: 157][Batch:2][Training Accuracy: 96 %][Loss: 0.0946577]
#
# [Epoch: 157] Validation accuracy: 100 %, Validation loss: 0.040772
# [Epoch: 158][Batch:2][Training Accuracy: 96 %][Loss: 0.0923503]
#
# [Epoch: 158] Validation accuracy: 100 %, Validation loss: 0.0408766
# [Epoch: 159][Batch:2][Training Accuracy: 96 %][Loss: 0.0917065]
#
# [Epoch: 159] Validation accuracy: 100 %, Validation loss: 0.0404712
# [Epoch: 160][Batch:2][Training Accuracy: 96 %][Loss: 0.089851]
#
# [Epoch: 160] Validation accuracy: 100 %, Validation loss: 0.0373189
# [Epoch: 161][Batch:2][Training Accuracy: 96 %][Loss: 0.0855965]
#
# [Epoch: 161] Validation accuracy: 100 %, Validation loss: 0.0340909
# [Epoch: 162][Batch:2][Training Accuracy: 97 %][Loss: 0.0816674]
#
# [Epoch: 162] Validation accuracy: 100 %, Validation loss: 0.0318712
# [Epoch: 163][Batch:2][Training Accuracy: 97 %][Loss: 0.0787511]
#
# [Epoch: 163] Validation accuracy: 100 %, Validation loss: 0.0302563
# [Epoch: 164][Batch:2][Training Accuracy: 97 %][Loss: 0.0763529]
#
# [Epoch: 164] Validation accuracy: 100 %, Validation loss: 0.0288821
# [Epoch: 165][Batch:2][Training Accuracy: 93 %][Loss: 1.06198]
#
# [Epoch: 165] Validation accuracy: 100 %, Validation loss: 0.0289389
# [Epoch: 166][Batch:2][Training Accuracy: 97 %][Loss: 0.0753958]
#
# [Epoch: 166] Validation accuracy: 100 %, Validation loss: 0.0311788
# [Epoch: 167][Batch:2][Training Accuracy: 97 %][Loss: 0.0782724]
#
# [Epoch: 167] Validation accuracy: 100 %, Validation loss: 0.0330904
# [Epoch: 168][Batch:2][Training Accuracy: 97 %][Loss: 0.0805111]
#
# [Epoch: 168] Validation accuracy: 100 %, Validation loss: 0.0342459
# [Epoch: 169][Batch:2][Training Accuracy: 97 %][Loss: 0.0815985]
#
# [Epoch: 169] Validation accuracy: 100 %, Validation loss: 0.0344715
# [Epoch: 170][Batch:2][Training Accuracy: 97 %][Loss: 0.0813959]
#
# [Epoch: 170] Validation accuracy: 100 %, Validation loss: 0.0338434
# [Epoch: 171][Batch:2][Training Accuracy: 97 %][Loss: 0.0800797]
#
# [Epoch: 171] Validation accuracy: 100 %, Validation loss: 0.032633
# [Epoch: 172][Batch:2][Training Accuracy: 94 %][Loss: 0.876211]
#
# [Epoch: 172] Validation accuracy: 100 %, Validation loss: 0.0333762
# [Epoch: 173][Batch:2][Training Accuracy: 97 %][Loss: 0.0812873]
#
# [Epoch: 173] Validation accuracy: 100 %, Validation loss: 0.038742
# [Epoch: 174][Batch:2][Training Accuracy: 96 %][Loss: 0.088688]
#
# [Epoch: 174] Validation accuracy: 100 %, Validation loss: 0.042733
# [Epoch: 175][Batch:2][Training Accuracy: 96 %][Loss: 0.0929792]
#
# [Epoch: 175] Validation accuracy: 100 %, Validation loss: 0.0414742
# [Epoch: 176][Batch:2][Training Accuracy: 96 %][Loss: 0.0911101]
#
# [Epoch: 176] Validation accuracy: 100 %, Validation loss: 0.0381865
# [Epoch: 177][Batch:2][Training Accuracy: 96 %][Loss: 0.0873504]
#
# [Epoch: 177] Validation accuracy: 100 %, Validation loss: 0.0355874
# [Epoch: 178][Batch:2][Training Accuracy: 96 %][Loss: 0.0843841]
#
# [Epoch: 178] Validation accuracy: 100 %, Validation loss: 0.0336352
# [Epoch: 179][Batch:2][Training Accuracy: 96 %][Loss: 0.0819194]
#
# [Epoch: 179] Validation accuracy: 100 %, Validation loss: 0.0317431
# [Epoch: 180][Batch:2][Training Accuracy: 96 %][Loss: 0.0791162]
#
# [Epoch: 180] Validation accuracy: 100 %, Validation loss: 0.0297004
# [Epoch: 181][Batch:2][Training Accuracy: 94 %][Loss: 0.776027]
#
# [Epoch: 181] Validation accuracy: 100 %, Validation loss: 0.0292323
# [Epoch: 182][Batch:2][Training Accuracy: 97 %][Loss: 0.0764365]
#
# [Epoch: 182] Validation accuracy: 100 %, Validation loss: 0.0318746
# [Epoch: 183][Batch:2][Training Accuracy: 95 %][Loss: 0.67404]
#
# [Epoch: 183] Validation accuracy: 100 %, Validation loss: 0.0365482
# [Epoch: 184][Batch:2][Training Accuracy: 96 %][Loss: 0.0885916]
#
# [Epoch: 184] Validation accuracy: 100 %, Validation loss: 0.0430452
# [Epoch: 185][Batch:2][Training Accuracy: 95 %][Loss: 0.0980457]
#
# [Epoch: 185] Validation accuracy: 100 %, Validation loss: 0.0457338
# [Epoch: 186][Batch:2][Training Accuracy: 95 %][Loss: 0.102447]
#
# [Epoch: 186] Validation accuracy: 100 %, Validation loss: 0.0447932
# [Epoch: 187][Batch:2][Training Accuracy: 95 %][Loss: 0.102306]
#
# [Epoch: 187] Validation accuracy: 100 %, Validation loss: 0.0422479
# [Epoch: 188][Batch:2][Training Accuracy: 95 %][Loss: 0.0994751]
#
# [Epoch: 188] Validation accuracy: 100 %, Validation loss: 0.0390376
# [Epoch: 189][Batch:2][Training Accuracy: 95 %][Loss: 0.0950517]
#
# [Epoch: 189] Validation accuracy: 100 %, Validation loss: 0.0357642
# [Epoch: 190][Batch:2][Training Accuracy: 95 %][Loss: 0.0899107]
#
# [Epoch: 190] Validation accuracy: 100 %, Validation loss: 0.0328684
# [Epoch: 191][Batch:2][Training Accuracy: 96 %][Loss: 0.0847035]
#
# [Epoch: 191] Validation accuracy: 100 %, Validation loss: 0.0304025
# [Epoch: 192][Batch:2][Training Accuracy: 96 %][Loss: 0.0796778]
#
# [Epoch: 192] Validation accuracy: 100 %, Validation loss: 0.0282245
# [Epoch: 193][Batch:2][Training Accuracy: 97 %][Loss: 0.0748753]
#
# [Epoch: 193] Validation accuracy: 100 %, Validation loss: 0.0262491
# [Epoch: 194][Batch:2][Training Accuracy: 97 %][Loss: 0.0703609]
#
# [Epoch: 194] Validation accuracy: 100 %, Validation loss: 0.0245094
# [Epoch: 195][Batch:2][Training Accuracy: 97 %][Loss: 0.0662487]
#
# [Epoch: 195] Validation accuracy: 100 %, Validation loss: 0.0230645
# [Epoch: 196][Batch:2][Training Accuracy: 97 %][Loss: 0.0626015]
#
# [Epoch: 196] Validation accuracy: 100 %, Validation loss: 0.0219073
# [Epoch: 197][Batch:2][Training Accuracy: 97 %][Loss: 0.0593708]
#
# [Epoch: 197] Validation accuracy: 100 %, Validation loss: 0.0209704
# [Epoch: 198][Batch:2][Training Accuracy: 98 %][Loss: 0.056445]
#
# [Epoch: 198] Validation accuracy: 100 %, Validation loss: 0.020181
# [Epoch: 199][Batch:2][Training Accuracy: 98 %][Loss: 0.0537345]
#
# [Epoch: 199] Validation accuracy: 100 %, Validation loss: 0.019494
# [Epoch: 200][Batch:2][Training Accuracy: 98 %][Loss: 0.0512113]
#
# [Epoch: 200] Validation accuracy: 100 %, Validation loss: 0.0188876
# [Epoch: 201][Batch:2][Training Accuracy: 98 %][Loss: 0.0488877]
#
# [Epoch: 201] Validation accuracy: 100 %, Validation loss: 0.0183412
# [Epoch: 202][Batch:2][Training Accuracy: 98 %][Loss: 0.0467722]
#
# [Epoch: 202] Validation accuracy: 100 %, Validation loss: 0.0178282
# [Epoch: 203][Batch:2][Training Accuracy: 98 %][Loss: 0.0448483]
#
# [Epoch: 203] Validation accuracy: 100 %, Validation loss: 0.0173256
# [Epoch: 204][Batch:2][Training Accuracy: 98 %][Loss: 0.0430867]
#
# [Epoch: 204] Validation accuracy: 100 %, Validation loss: 0.0168269
# [Epoch: 205][Batch:2][Training Accuracy: 98 %][Loss: 0.0414642]
#
# [Epoch: 205] Validation accuracy: 100 %, Validation loss: 0.0163408
# [Epoch: 206][Batch:2][Training Accuracy: 98 %][Loss: 0.0399669]
#
# [Epoch: 206] Validation accuracy: 100 %, Validation loss: 0.0158785
# [Epoch: 207][Batch:2][Training Accuracy: 98 %][Loss: 0.0385836]
#
# [Epoch: 207] Validation accuracy: 100 %, Validation loss: 0.0154453
# [Epoch: 208][Batch:2][Training Accuracy: 93 %][Loss: 0.931913]
#
# [Epoch: 208] Validation accuracy: 100 %, Validation loss: 0.0157266
# [Epoch: 209][Batch:2][Training Accuracy: 99 %][Loss: 0.0396491]
#
# [Epoch: 209] Validation accuracy: 100 %, Validation loss: 0.0205668
# [Epoch: 210][Batch:2][Training Accuracy: 98 %][Loss: 0.0485729]
#
# [Epoch: 210] Validation accuracy: 100 %, Validation loss: 0.0214366
# [Epoch: 211][Batch:2][Training Accuracy: 98 %][Loss: 0.0522761]
#
# [Epoch: 211] Validation accuracy: 100 %, Validation loss: 0.0198352
# [Epoch: 212][Batch:2][Training Accuracy: 98 %][Loss: 0.052716]
#
# [Epoch: 212] Validation accuracy: 100 %, Validation loss: 0.0189898
# [Epoch: 213][Batch:2][Training Accuracy: 97 %][Loss: 0.0522741]
#
# [Epoch: 213] Validation accuracy: 100 %, Validation loss: 0.0184827
# [Epoch: 214][Batch:2][Training Accuracy: 97 %][Loss: 0.051923]
#
# [Epoch: 214] Validation accuracy: 100 %, Validation loss: 0.0180313
# [Epoch: 215][Batch:2][Training Accuracy: 97 %][Loss: 0.0512127]
#
# [Epoch: 215] Validation accuracy: 100 %, Validation loss: 0.0174255
# [Epoch: 216][Batch:2][Training Accuracy: 98 %][Loss: 0.0483279]
#
# [Epoch: 216] Validation accuracy: 100 %, Validation loss: 0.0168596
# [Epoch: 217][Batch:2][Training Accuracy: 98 %][Loss: 0.0460364]
#
# [Epoch: 217] Validation accuracy: 100 %, Validation loss: 0.0163717
# [Epoch: 218][Batch:2][Training Accuracy: 98 %][Loss: 0.0441681]
#
# [Epoch: 218] Validation accuracy: 100 %, Validation loss: 0.0159148
# [Epoch: 219][Batch:2][Training Accuracy: 98 %][Loss: 0.042428]
#
# [Epoch: 219] Validation accuracy: 100 %, Validation loss: 0.0154465
# [Epoch: 220][Batch:2][Training Accuracy: 98 %][Loss: 0.0407134]
#
# [Epoch: 220] Validation accuracy: 100 %, Validation loss: 0.0149524
# [Epoch: 221][Batch:2][Training Accuracy: 99 %][Loss: 0.0390152]
#
# [Epoch: 221] Validation accuracy: 100 %, Validation loss: 0.0144377
# [Epoch: 222][Batch:2][Training Accuracy: 99 %][Loss: 0.0373633]
#
# [Epoch: 222] Validation accuracy: 100 %, Validation loss: 0.0139171
# [Epoch: 223][Batch:2][Training Accuracy: 94 %][Loss: 0.724552]
#
# [Epoch: 223] Validation accuracy: 100 %, Validation loss: 0.0136052
# [Epoch: 224][Batch:2][Training Accuracy: 99 %][Loss: 0.0362753]
#
# [Epoch: 224] Validation accuracy: 100 %, Validation loss: 0.0139121
# [Epoch: 225][Batch:2][Training Accuracy: 99 %][Loss: 0.0384233]
#
# [Epoch: 225] Validation accuracy: 100 %, Validation loss: 0.0143026
# [Epoch: 226][Batch:2][Training Accuracy: 99 %][Loss: 0.0402881]
#
# [Epoch: 226] Validation accuracy: 100 %, Validation loss: 0.014595
# [Epoch: 227][Batch:2][Training Accuracy: 98 %][Loss: 0.041446]
#
# [Epoch: 227] Validation accuracy: 100 %, Validation loss: 0.0146998
# [Epoch: 228][Batch:2][Training Accuracy: 98 %][Loss: 0.0417564]
#
# [Epoch: 228] Validation accuracy: 100 %, Validation loss: 0.0146277
# [Epoch: 229][Batch:2][Training Accuracy: 98 %][Loss: 0.0413314]
#
# [Epoch: 229] Validation accuracy: 100 %, Validation loss: 0.0144335
# [Epoch: 230][Batch:2][Training Accuracy: 99 %][Loss: 0.0404011]
#
# [Epoch: 230] Validation accuracy: 100 %, Validation loss: 0.0141601
# [Epoch: 231][Batch:2][Training Accuracy: 98 %][Loss: 0.0391786]
#
# [Epoch: 231] Validation accuracy: 100 %, Validation loss: 0.013827
# [Epoch: 232][Batch:2][Training Accuracy: 99 %][Loss: 0.0378082]
#
# [Epoch: 232] Validation accuracy: 100 %, Validation loss: 0.0134446
# [Epoch: 233][Batch:2][Training Accuracy: 95 %][Loss: 0.57459]
#
# [Epoch: 233] Validation accuracy: 100 %, Validation loss: 0.013657
# [Epoch: 234][Batch:2][Training Accuracy: 99 %][Loss: 0.0376583]
#
# [Epoch: 234] Validation accuracy: 100 %, Validation loss: 0.0149626
# [Epoch: 235][Batch:2][Training Accuracy: 98 %][Loss: 0.0412612]
#
# [Epoch: 235] Validation accuracy: 100 %, Validation loss: 0.0157904
# [Epoch: 236][Batch:2][Training Accuracy: 96 %][Loss: 0.453642]
#
# [Epoch: 236] Validation accuracy: 100 %, Validation loss: 0.0158543
# [Epoch: 237][Batch:2][Training Accuracy: 98 %][Loss: 0.0477555]
#
# [Epoch: 237] Validation accuracy: 100 %, Validation loss: 0.0159217
# [Epoch: 238][Batch:2][Training Accuracy: 97 %][Loss: 0.0521428]
#
# [Epoch: 238] Validation accuracy: 100 %, Validation loss: 0.0161536
# [Epoch: 239][Batch:2][Training Accuracy: 97 %][Loss: 0.0550003]
#
# [Epoch: 239] Validation accuracy: 100 %, Validation loss: 0.0164377
# [Epoch: 240][Batch:2][Training Accuracy: 96 %][Loss: 0.0564127]
#
# [Epoch: 240] Validation accuracy: 100 %, Validation loss: 0.0164341
# [Epoch: 241][Batch:2][Training Accuracy: 96 %][Loss: 0.0562283]
#
# [Epoch: 241] Validation accuracy: 100 %, Validation loss: 0.015978
# [Epoch: 242][Batch:2][Training Accuracy: 96 %][Loss: 0.0544692]
#
# [Epoch: 242] Validation accuracy: 100 %, Validation loss: 0.0152911
# [Epoch: 243][Batch:2][Training Accuracy: 97 %][Loss: 0.0517523]
#
# [Epoch: 243] Validation accuracy: 100 %, Validation loss: 0.014649
# [Epoch: 244][Batch:2][Training Accuracy: 97 %][Loss: 0.0488005]
#
# [Epoch: 244] Validation accuracy: 100 %, Validation loss: 0.0141306
# [Epoch: 245][Batch:2][Training Accuracy: 98 %][Loss: 0.0459798]
#
# [Epoch: 245] Validation accuracy: 100 %, Validation loss: 0.0136583
# [Epoch: 246][Batch:2][Training Accuracy: 98 %][Loss: 0.0432791]
#
# [Epoch: 246] Validation accuracy: 100 %, Validation loss: 0.0131133
# [Epoch: 247][Batch:2][Training Accuracy: 98 %][Loss: 0.0406224]
#
# [Epoch: 247] Validation accuracy: 100 %, Validation loss: 0.0124738
# [Epoch: 248][Batch:2][Training Accuracy: 96 %][Loss: 0.422883]
#
# [Epoch: 248] Validation accuracy: 100 %, Validation loss: 0.0128984
# [Epoch: 249][Batch:2][Training Accuracy: 98 %][Loss: 0.0404239]
#
# [Epoch: 249] Validation accuracy: 100 %, Validation loss: 0.018499
# [Epoch: 250][Batch:2][Training Accuracy: 98 %][Loss: 0.0532488]
#
# [Epoch: 250] Validation accuracy: 100 %, Validation loss: 0.0146433
# [Epoch: 251][Batch:2][Training Accuracy: 98 %][Loss: 0.046924]
#
# [Epoch: 251] Validation accuracy: 100 %, Validation loss: 0.0131272
# [Epoch: 252][Batch:2][Training Accuracy: 98 %][Loss: 0.322468]
#
# [Epoch: 252] Validation accuracy: 100 %, Validation loss: 0.0131385
# [Epoch: 253][Batch:2][Training Accuracy: 97 %][Loss: 0.047043]
#
# [Epoch: 253] Validation accuracy: 100 %, Validation loss: 0.0128879
# [Epoch: 254][Batch:2][Training Accuracy: 97 %][Loss: 0.0495491]
#
# [Epoch: 254] Validation accuracy: 100 %, Validation loss: 0.0128298
# [Epoch: 255][Batch:2][Training Accuracy: 97 %][Loss: 0.0505379]
#
# [Epoch: 255] Validation accuracy: 100 %, Validation loss: 0.0128372
# [Epoch: 256][Batch:2][Training Accuracy: 97 %][Loss: 0.0520656]
#
# [Epoch: 256] Validation accuracy: 100 %, Validation loss: 0.0125224
# [Epoch: 257][Batch:2][Training Accuracy: 97 %][Loss: 0.0508239]
#
# [Epoch: 257] Validation accuracy: 100 %, Validation loss: 0.0122855
# [Epoch: 258][Batch:2][Training Accuracy: 97 %][Loss: 0.0497559]
#
# [Epoch: 258] Validation accuracy: 100 %, Validation loss: 0.0117084
# [Epoch: 259][Batch:2][Training Accuracy: 98 %][Loss: 0.0470766]
#
# [Epoch: 259] Validation accuracy: 100 %, Validation loss: 0.0109836
# [Epoch: 260][Batch:2][Training Accuracy: 98 %][Loss: 0.0437859]
#
# [Epoch: 260] Validation accuracy: 100 %, Validation loss: 0.0103536
# [Epoch: 261][Batch:2][Training Accuracy: 98 %][Loss: 0.0406097]
#
# [Epoch: 261] Validation accuracy: 100 %, Validation loss: 0.00987528
# [Epoch: 262][Batch:2][Training Accuracy: 98 %][Loss: 0.0377638]
#
# [Epoch: 262] Validation accuracy: 100 %, Validation loss: 0.00949694
# [Epoch: 263][Batch:2][Training Accuracy: 98 %][Loss: 0.0352195]
#
# [Epoch: 263] Validation accuracy: 100 %, Validation loss: 0.00915109
# [Epoch: 264][Batch:2][Training Accuracy: 99 %][Loss: 0.0328977]
#
# [Epoch: 264] Validation accuracy: 100 %, Validation loss: 0.00880164
# [Epoch: 265][Batch:2][Training Accuracy: 99 %][Loss: 0.0307476]
#
# [Epoch: 265] Validation accuracy: 100 %, Validation loss: 0.00845086
# [Epoch: 266][Batch:2][Training Accuracy: 99 %][Loss: 0.0287615]
#
# [Epoch: 266] Validation accuracy: 100 %, Validation loss: 0.00811868
# [Epoch: 267][Batch:2][Training Accuracy: 96 %][Loss: 0.413668]
#
# [Epoch: 267] Validation accuracy: 100 %, Validation loss: 0.00796235
# [Epoch: 268][Batch:2][Training Accuracy: 99 %][Loss: 0.0275429]
#
# [Epoch: 268] Validation accuracy: 100 %, Validation loss: 0.00833696
# [Epoch: 269][Batch:2][Training Accuracy: 99 %][Loss: 0.0304749]
#
# [Epoch: 269] Validation accuracy: 100 %, Validation loss: 0.0088259
# [Epoch: 270][Batch:2][Training Accuracy: 98 %][Loss: 0.0330943]
#
# [Epoch: 270] Validation accuracy: 100 %, Validation loss: 0.00907843
# [Epoch: 271][Batch:2][Training Accuracy: 98 %][Loss: 0.0345915]
#
# [Epoch: 271] Validation accuracy: 100 %, Validation loss: 0.00896794
# [Epoch: 272][Batch:2][Training Accuracy: 98 %][Loss: 0.0347466]
#
# [Epoch: 272] Validation accuracy: 100 %, Validation loss: 0.00862357
# [Epoch: 273][Batch:2][Training Accuracy: 98 %][Loss: 0.0338802]
#
# [Epoch: 273] Validation accuracy: 100 %, Validation loss: 0.00822035
# [Epoch: 274][Batch:2][Training Accuracy: 98 %][Loss: 0.0324619]
#
# [Epoch: 274] Validation accuracy: 100 %, Validation loss: 0.00784794
# [Epoch: 275][Batch:2][Training Accuracy: 99 %][Loss: 0.0308412]
#
# [Epoch: 275] Validation accuracy: 100 %, Validation loss: 0.00752736
# [Epoch: 276][Batch:2][Training Accuracy: 99 %][Loss: 0.0292112]
#
# [Epoch: 276] Validation accuracy: 100 %, Validation loss: 0.00725238
# [Epoch: 277][Batch:2][Training Accuracy: 99 %][Loss: 0.0276579]
#
# [Epoch: 277] Validation accuracy: 100 %, Validation loss: 0.00700992
# [Epoch: 278][Batch:2][Training Accuracy: 99 %][Loss: 0.0262081]
#
# [Epoch: 278] Validation accuracy: 100 %, Validation loss: 0.00678872
# [Epoch: 279][Batch:2][Training Accuracy: 99 %][Loss: 0.0248628]
#
# [Epoch: 279] Validation accuracy: 100 %, Validation loss: 0.00658193
# [Epoch: 280][Batch:2][Training Accuracy: 99 %][Loss: 0.0236156]
#
# [Epoch: 280] Validation accuracy: 100 %, Validation loss: 0.00638733
# [Epoch: 281][Batch:2][Training Accuracy: 99 %][Loss: 0.0224601]
#
# [Epoch: 281] Validation accuracy: 100 %, Validation loss: 0.00620496
# [Epoch: 282][Batch:2][Training Accuracy: 99 %][Loss: 0.0213918]
#
# [Epoch: 282] Validation accuracy: 100 %, Validation loss: 0.00603559
# [Epoch: 283][Batch:2][Training Accuracy: 99 %][Loss: 0.0204063]
#
# [Epoch: 283] Validation accuracy: 100 %, Validation loss: 0.00587948
# [Epoch: 284][Batch:2][Training Accuracy: 99 %][Loss: 0.0194992]
#
# [Epoch: 284] Validation accuracy: 100 %, Validation loss: 0.0057362
# [Epoch: 285][Batch:2][Training Accuracy: 99 %][Loss: 0.0186654]
#
# [Epoch: 285] Validation accuracy: 100 %, Validation loss: 0.00560472
# [Epoch: 286][Batch:2][Training Accuracy: 99 %][Loss: 0.0178994]
#
# [Epoch: 286] Validation accuracy: 100 %, Validation loss: 0.00548344
# [Epoch: 287][Batch:2][Training Accuracy: 99 %][Loss: 0.0171955]
#
# [Epoch: 287] Validation accuracy: 100 %, Validation loss: 0.00537101
# [Epoch: 288][Batch:2][Training Accuracy: 99 %][Loss: 0.0165482]
#
# [Epoch: 288] Validation accuracy: 100 %, Validation loss: 0.00526609
# [Epoch: 289][Batch:2][Training Accuracy: 99 %][Loss: 0.0159524]
#
# [Epoch: 289] Validation accuracy: 100 %, Validation loss: 0.00516741
# [Epoch: 290][Batch:2][Training Accuracy: 99 %][Loss: 0.0154032]
#
# [Epoch: 290] Validation accuracy: 100 %, Validation loss: 0.00507396
# [Epoch: 291][Batch:2][Training Accuracy: 99 %][Loss: 0.0148961]
#
# [Epoch: 291] Validation accuracy: 100 %, Validation loss: 0.00498493
# [Epoch: 292][Batch:2][Training Accuracy: 99 %][Loss: 0.014427]
#
# [Epoch: 292] Validation accuracy: 100 %, Validation loss: 0.00489941
# [Epoch: 293][Batch:2][Training Accuracy: 99 %][Loss: 0.0139919]
#
# [Epoch: 293] Validation accuracy: 100 %, Validation loss: 0.0048169
# [Epoch: 294][Batch:2][Training Accuracy: 99 %][Loss: 0.0135873]
#
# [Epoch: 294] Validation accuracy: 100 %, Validation loss: 0.00473693
# [Epoch: 295][Batch:2][Training Accuracy: 99 %][Loss: 0.01321]
#
# [Epoch: 295] Validation accuracy: 100 %, Validation loss: 0.00465901
# [Epoch: 296][Batch:2][Training Accuracy: 94 %][Loss: 0.601559]
#
# [Epoch: 296] Validation accuracy: 100 %, Validation loss: 0.00458602
# [Epoch: 297][Batch:2][Training Accuracy: 99 %][Loss: 0.0137598]
#
# [Epoch: 297] Validation accuracy: 100 %, Validation loss: 0.00486168
# [Epoch: 298][Batch:2][Training Accuracy: 99 %][Loss: 0.0164238]
#
# [Epoch: 298] Validation accuracy: 100 %, Validation loss: 0.00538923
# [Epoch: 299][Batch:2][Training Accuracy: 99 %][Loss: 0.0191449]
#
# [Epoch: 299] Validation accuracy: 100 %, Validation loss: 0.00598572
# [Epoch: 300][Batch:2][Training Accuracy: 99 %][Loss: 0.0214543]
#
# [Epoch: 300] Validation accuracy: 100 %, Validation loss: 0.0063885
# [Epoch: 301][Batch:2][Training Accuracy: 96 %][Loss: 0.385607]
#
# [Epoch: 301] Validation accuracy: 100 %, Validation loss: 0.00603479
# [Epoch: 302][Batch:2][Training Accuracy: 99 %][Loss: 0.0243144]
#
# [Epoch: 302] Validation accuracy: 100 %, Validation loss: 0.00576161
# [Epoch: 303][Batch:2][Training Accuracy: 99 %][Loss: 0.0268941]
#
# [Epoch: 303] Validation accuracy: 100 %, Validation loss: 0.00587874
# [Epoch: 304][Batch:2][Training Accuracy: 98 %][Loss: 0.0293976]
#
# [Epoch: 304] Validation accuracy: 100 %, Validation loss: 0.00611758
# [Epoch: 305][Batch:2][Training Accuracy: 98 %][Loss: 0.0312019]
#
# [Epoch: 305] Validation accuracy: 100 %, Validation loss: 0.00630877
# [Epoch: 306][Batch:2][Training Accuracy: 98 %][Loss: 0.251268]
#
# [Epoch: 306] Validation accuracy: 100 %, Validation loss: 0.00635345
# [Epoch: 307][Batch:2][Training Accuracy: 98 %][Loss: 0.0340548]
#
# [Epoch: 307] Validation accuracy: 100 %, Validation loss: 0.00634812
# [Epoch: 308][Batch:2][Training Accuracy: 98 %][Loss: 0.0366965]
#
# [Epoch: 308] Validation accuracy: 100 %, Validation loss: 0.00638934
# [Epoch: 309][Batch:2][Training Accuracy: 98 %][Loss: 0.0383029]
#
# [Epoch: 309] Validation accuracy: 100 %, Validation loss: 0.00641775
# [Epoch: 310][Batch:2][Training Accuracy: 98 %][Loss: 0.0388372]
#
# [Epoch: 310] Validation accuracy: 100 %, Validation loss: 0.00638681
# [Epoch: 311][Batch:2][Training Accuracy: 97 %][Loss: 0.0384259]
#
# [Epoch: 311] Validation accuracy: 100 %, Validation loss: 0.00628239
# [Epoch: 312][Batch:2][Training Accuracy: 98 %][Loss: 0.0372801]
#
# [Epoch: 312] Validation accuracy: 100 %, Validation loss: 0.00612105
# [Epoch: 313][Batch:2][Training Accuracy: 98 %][Loss: 0.0356425]
#
# [Epoch: 313] Validation accuracy: 100 %, Validation loss: 0.00593197
# [Epoch: 314][Batch:2][Training Accuracy: 98 %][Loss: 0.0337389]
#
# [Epoch: 314] Validation accuracy: 100 %, Validation loss: 0.00573926
# [Epoch: 315][Batch:2][Training Accuracy: 98 %][Loss: 0.0317469]
#
# [Epoch: 315] Validation accuracy: 100 %, Validation loss: 0.00555612
# [Epoch: 316][Batch:2][Training Accuracy: 98 %][Loss: 0.0297869]
#
# [Epoch: 316] Validation accuracy: 100 %, Validation loss: 0.00538585
# [Epoch: 317][Batch:2][Training Accuracy: 98 %][Loss: 0.0279289]
#
# [Epoch: 317] Validation accuracy: 100 %, Validation loss: 0.00522639
# [Epoch: 318][Batch:2][Training Accuracy: 99 %][Loss: 0.0262067]
#
# [Epoch: 318] Validation accuracy: 100 %, Validation loss: 0.00507505
# [Epoch: 319][Batch:2][Training Accuracy: 99 %][Loss: 0.0246313]
#
# [Epoch: 319] Validation accuracy: 100 %, Validation loss: 0.00493081
# [Epoch: 320][Batch:2][Training Accuracy: 99 %][Loss: 0.023201]
#
# [Epoch: 320] Validation accuracy: 100 %, Validation loss: 0.00479414
# [Epoch: 321][Batch:2][Training Accuracy: 99 %][Loss: 0.0219078]
#
# [Epoch: 321] Validation accuracy: 100 %, Validation loss: 0.00466611
# [Epoch: 322][Batch:2][Training Accuracy: 99 %][Loss: 0.0207414]
#
# [Epoch: 322] Validation accuracy: 100 %, Validation loss: 0.00454715
# [Epoch: 323][Batch:2][Training Accuracy: 99 %][Loss: 0.0196898]
#
# [Epoch: 323] Validation accuracy: 100 %, Validation loss: 0.00443729
# [Epoch: 324][Batch:2][Training Accuracy: 99 %][Loss: 0.0187412]
#
# [Epoch: 324] Validation accuracy: 100 %, Validation loss: 0.00433562
# [Epoch: 325][Batch:2][Training Accuracy: 99 %][Loss: 0.0178841]
#
# [Epoch: 325] Validation accuracy: 100 %, Validation loss: 0.00424109
# [Epoch: 326][Batch:2][Training Accuracy: 99 %][Loss: 0.0171079]
#
# [Epoch: 326] Validation accuracy: 100 %, Validation loss: 0.00415258
# [Epoch: 327][Batch:2][Training Accuracy: 99 %][Loss: 0.0164028]
#
# [Epoch: 327] Validation accuracy: 100 %, Validation loss: 0.00406919
# [Epoch: 328][Batch:2][Training Accuracy: 99 %][Loss: 0.0157603]
#
# [Epoch: 328] Validation accuracy: 100 %, Validation loss: 0.00399
# [Epoch: 329][Batch:2][Training Accuracy: 99 %][Loss: 0.0151728]
#
# [Epoch: 329] Validation accuracy: 100 %, Validation loss: 0.00391447
# [Epoch: 330][Batch:2][Training Accuracy: 99 %][Loss: 0.0146337]
#
# [Epoch: 330] Validation accuracy: 100 %, Validation loss: 0.00384215
# [Epoch: 331][Batch:2][Training Accuracy: 99 %][Loss: 0.0141373]
#
# [Epoch: 331] Validation accuracy: 100 %, Validation loss: 0.00377283
# [Epoch: 332][Batch:2][Training Accuracy: 99 %][Loss: 0.0136786]
#
# [Epoch: 332] Validation accuracy: 100 %, Validation loss: 0.00370627
# [Epoch: 333][Batch:2][Training Accuracy: 99 %][Loss: 0.0132536]
#
# [Epoch: 333] Validation accuracy: 100 %, Validation loss: 0.00364234
# [Epoch: 334][Batch:2][Training Accuracy: 99 %][Loss: 0.0128585]
#
# [Epoch: 334] Validation accuracy: 100 %, Validation loss: 0.00358096
# [Epoch: 335][Batch:2][Training Accuracy: 99 %][Loss: 0.01249]
#
# [Epoch: 335] Validation accuracy: 100 %, Validation loss: 0.00352197
# [Epoch: 336][Batch:2][Training Accuracy: 99 %][Loss: 0.0121454]
#
# [Epoch: 336] Validation accuracy: 100 %, Validation loss: 0.00346539
# [Epoch: 337][Batch:2][Training Accuracy: 99 %][Loss: 0.0118224]
#
# [Epoch: 337] Validation accuracy: 100 %, Validation loss: 0.00341122
# [Epoch: 338][Batch:2][Training Accuracy: 99 %][Loss: 0.0115189]
#
# [Epoch: 338] Validation accuracy: 100 %, Validation loss: 0.00335914
# [Epoch: 339][Batch:2][Training Accuracy: 99 %][Loss: 0.0112328]
#
# [Epoch: 339] Validation accuracy: 100 %, Validation loss: 0.00330926
# [Epoch: 340][Batch:2][Training Accuracy: 99 %][Loss: 0.0109628]
#
# [Epoch: 340] Validation accuracy: 100 %, Validation loss: 0.00326133
# [Epoch: 341][Batch:2][Training Accuracy: 99 %][Loss: 0.0107073]
#
# [Epoch: 341] Validation accuracy: 100 %, Validation loss: 0.0032154
# [Epoch: 342][Batch:2][Training Accuracy: 99 %][Loss: 0.010465]
#
# [Epoch: 342] Validation accuracy: 100 %, Validation loss: 0.00317128
# [Epoch: 343][Batch:2][Training Accuracy: 99 %][Loss: 0.0102349]
#
# [Epoch: 343] Validation accuracy: 100 %, Validation loss: 0.00312887
# [Epoch: 344][Batch:2][Training Accuracy: 99 %][Loss: 0.010016]
#
# [Epoch: 344] Validation accuracy: 100 %, Validation loss: 0.00308813
# [Epoch: 345][Batch:2][Training Accuracy: 99 %][Loss: 0.0098074]
#
# [Epoch: 345] Validation accuracy: 100 %, Validation loss: 0.00304875
# [Epoch: 346][Batch:2][Training Accuracy: 99 %][Loss: 0.00960822]
#
# [Epoch: 346] Validation accuracy: 100 %, Validation loss: 0.00301082
# [Epoch: 347][Batch:2][Training Accuracy: 99 %][Loss: 0.00941782]
#
# [Epoch: 347] Validation accuracy: 100 %, Validation loss: 0.00297415
# [Epoch: 348][Batch:2][Training Accuracy: 95 %][Loss: 0.571426]
#
# [Epoch: 348] Validation accuracy: 100 %, Validation loss: 0.00294064
# [Epoch: 349][Batch:2][Training Accuracy: 96 %][Loss: 0.455268]
#
# [Epoch: 349] Validation accuracy: 100 %, Validation loss: 0.00338457
# [Epoch: 350][Batch:2][Training Accuracy: 99 %][Loss: 0.0137197]
#
# [Epoch: 350] Validation accuracy: 100 %, Validation loss: 0.00497869
# [Epoch: 351][Batch:2][Training Accuracy: 99 %][Loss: 0.0211309]
#
# [Epoch: 351] Validation accuracy: 100 %, Validation loss: 0.00861054
# [Epoch: 352][Batch:2][Training Accuracy: 98 %][Loss: 0.0306278]
#
# [Epoch: 352] Validation accuracy: 100 %, Validation loss: 0.0107283
# [Epoch: 353][Batch:2][Training Accuracy: 98 %][Loss: 0.0352833]
#
# [Epoch: 353] Validation accuracy: 100 %, Validation loss: 0.00825161
# [Epoch: 354][Batch:2][Training Accuracy: 98 %][Loss: 0.0346503]
#
# [Epoch: 354] Validation accuracy: 100 %, Validation loss: 0.00665626
# [Epoch: 355][Batch:2][Training Accuracy: 98 %][Loss: 0.0330524]
#
# [Epoch: 355] Validation accuracy: 100 %, Validation loss: 0.00579716
# [Epoch: 356][Batch:2][Training Accuracy: 98 %][Loss: 0.0312625]
#
# [Epoch: 356] Validation accuracy: 100 %, Validation loss: 0.00528613
# [Epoch: 357][Batch:2][Training Accuracy: 98 %][Loss: 0.0295272]
#
# [Epoch: 357] Validation accuracy: 100 %, Validation loss: 0.00495737
# [Epoch: 358][Batch:2][Training Accuracy: 98 %][Loss: 0.0279109]
#
# [Epoch: 358] Validation accuracy: 100 %, Validation loss: 0.00472926
# [Epoch: 359][Batch:2][Training Accuracy: 98 %][Loss: 0.0264026]
#
# [Epoch: 359] Validation accuracy: 100 %, Validation loss: 0.00455398
# [Epoch: 360][Batch:2][Training Accuracy: 98 %][Loss: 0.0249774]
#
# [Epoch: 360] Validation accuracy: 100 %, Validation loss: 0.00440358
# [Epoch: 361][Batch:2][Training Accuracy: 99 %][Loss: 0.023617]
#
# ...
#
# [Epoch: 882] Validation accuracy: 100 %, Validation loss: 0.000383148
# [Epoch: 883][Batch:2][Training Accuracy: 98 %][Loss: 0.0169993]
#
# [Epoch: 883] Validation accuracy: 100 %, Validation loss: 0.000384947
# [Epoch: 884][Batch:2][Training Accuracy: 98 %][Loss: 0.0174865]
#
# [Epoch: 884] Validation accuracy: 100 %, Validation loss: 0.000384549
# [Epoch: 885][Batch:2][Training Accuracy: 98 %][Loss: 0.017606]
#
# [Epoch: 885] Validation accuracy: 100 %, Validation loss: 0.000382373
# [Epoch: 886][Batch:2][Training Accuracy: 98 %][Loss: 0.0174219]
#
# [Epoch: 886] Validation accuracy: 100 %, Validation loss: 0.000379028
# [Epoch: 887][Batch:2][Training Accuracy: 98 %][Loss: 0.0170025]
#
# [Epoch: 887] Validation accuracy: 100 %, Validation loss: 0.000374887
# [Epoch: 888][Batch:2][Training Accuracy: 98 %][Loss: 0.0164133]
#
# [Epoch: 888] Validation accuracy: 100 %, Validation loss: 0.00037051
# [Epoch: 889][Batch:2][Training Accuracy: 98 %][Loss: 0.0157116]
#
# [Epoch: 889] Validation accuracy: 100 %, Validation loss: 0.000366035
# [Epoch: 890][Batch:2][Training Accuracy: 98 %][Loss: 0.0149446]
#
# [Epoch: 890] Validation accuracy: 100 %, Validation loss: 0.00036178
# [Epoch: 891][Batch:2][Training Accuracy: 98 %][Loss: 0.0141497]
#
# [Epoch: 891] Validation accuracy: 100 %, Validation loss: 0.000357872
# [Epoch: 892][Batch:2][Training Accuracy: 99 %][Loss: 0.013355]
#
# [Epoch: 892] Validation accuracy: 100 %, Validation loss: 0.00035419
# [Epoch: 893][Batch:2][Training Accuracy: 99 %][Loss: 0.0125808]
#
# [Epoch: 893] Validation accuracy: 100 %, Validation loss: 0.00035092
# [Epoch: 894][Batch:2][Training Accuracy: 99 %][Loss: 0.011841]
#
# [Epoch: 894] Validation accuracy: 100 %, Validation loss: 0.000347865
# [Epoch: 895][Batch:2][Training Accuracy: 99 %][Loss: 0.0111443]
#
# [Epoch: 895] Validation accuracy: 100 %, Validation loss: 0.000345151
# [Epoch: 896][Batch:2][Training Accuracy: 99 %][Loss: 0.0104955]
#
# [Epoch: 896] Validation accuracy: 100 %, Validation loss: 0.000342649
# [Epoch: 897][Batch:2][Training Accuracy: 99 %][Loss: 0.00989633]
#
# [Epoch: 897] Validation accuracy: 100 %, Validation loss: 0.000340311
# [Epoch: 898][Batch:2][Training Accuracy: 99 %][Loss: 0.00934627]
#
# [Epoch: 898] Validation accuracy: 100 %, Validation loss: 0.000338088
# [Epoch: 899][Batch:2][Training Accuracy: 99 %][Loss: 0.00884321]
#
# [Epoch: 899] Validation accuracy: 100 %, Validation loss: 0.000336009
# [Epoch: 900][Batch:2][Training Accuracy: 99 %][Loss: 0.00838432]
#
# [Epoch: 900] Validation accuracy: 100 %, Validation loss: 0.000334023
# [Epoch: 901][Batch:2][Training Accuracy: 99 %][Loss: 0.00796605]
#
# [Epoch: 901] Validation accuracy: 100 %, Validation loss: 0.000332187
# [Epoch: 902][Batch:2][Training Accuracy: 99 %][Loss: 0.00758482]
#
# [Epoch: 902] Validation accuracy: 100 %, Validation loss: 0.00033028
# [Epoch: 903][Batch:2][Training Accuracy: 99 %][Loss: 0.00723677]
#
# [Epoch: 903] Validation accuracy: 100 %, Validation loss: 0.000328523
# [Epoch: 904][Batch:2][Training Accuracy: 99 %][Loss: 0.00691864]
#
# [Epoch: 904] Validation accuracy: 100 %, Validation loss: 0.000326773
# [Epoch: 905][Batch:2][Training Accuracy: 99 %][Loss: 0.00662709]
#
# [Epoch: 905] Validation accuracy: 100 %, Validation loss: 0.000325002
# [Epoch: 906][Batch:2][Training Accuracy: 99 %][Loss: 0.00635917]
#
# [Epoch: 906] Validation accuracy: 100 %, Validation loss: 0.000323389
# [Epoch: 907][Batch:2][Training Accuracy: 99 %][Loss: 0.00611241]
#
# [Epoch: 907] Validation accuracy: 100 %, Validation loss: 0.000321725
# [Epoch: 908][Batch:2][Training Accuracy: 99 %][Loss: 0.00588438]
#
# [Epoch: 908] Validation accuracy: 100 %, Validation loss: 0.000320126
# [Epoch: 909][Batch:2][Training Accuracy: 98 %][Loss: 0.162127]
#
# [Epoch: 909] Validation accuracy: 100 %, Validation loss: 0.000315924
# [Epoch: 910][Batch:2][Training Accuracy: 98 %][Loss: 0.141842]
#
# [Epoch: 910] Validation accuracy: 100 %, Validation loss: 0.000312275
# [Epoch: 911][Batch:2][Training Accuracy: 99 %][Loss: 0.00701562]
#
# [Epoch: 911] Validation accuracy: 100 %, Validation loss: 0.000315329
# [Epoch: 912][Batch:2][Training Accuracy: 99 %][Loss: 0.00872295]
#
# [Epoch: 912] Validation accuracy: 100 %, Validation loss: 0.000322313
# [Epoch: 913][Batch:2][Training Accuracy: 99 %][Loss: 0.0103564]
#
# [Epoch: 913] Validation accuracy: 100 %, Validation loss: 0.000330215
# [Epoch: 914][Batch:2][Training Accuracy: 99 %][Loss: 0.011725]
#
# [Epoch: 914] Validation accuracy: 100 %, Validation loss: 0.00033735
# [Epoch: 915][Batch:2][Training Accuracy: 98 %][Loss: 0.012731]
#
# [Epoch: 915] Validation accuracy: 100 %, Validation loss: 0.000342656
# [Epoch: 916][Batch:2][Training Accuracy: 98 %][Loss: 0.0133538]
#
# [Epoch: 916] Validation accuracy: 100 %, Validation loss: 0.000345782
# [Epoch: 917][Batch:2][Training Accuracy: 98 %][Loss: 0.0136256]
#
# [Epoch: 917] Validation accuracy: 100 %, Validation loss: 0.000346722
# [Epoch: 918][Batch:2][Training Accuracy: 98 %][Loss: 0.0136062]
#
# [Epoch: 918] Validation accuracy: 100 %, Validation loss: 0.000345883
# [Epoch: 919][Batch:2][Training Accuracy: 98 %][Loss: 0.0133634]
#
# [Epoch: 919] Validation accuracy: 100 %, Validation loss: 0.000343688
# [Epoch: 920][Batch:2][Training Accuracy: 98 %][Loss: 0.0129611]
#
# [Epoch: 920] Validation accuracy: 100 %, Validation loss: 0.000340835
# [Epoch: 921][Batch:2][Training Accuracy: 98 %][Loss: 0.0124533]
#
# [Epoch: 921] Validation accuracy: 100 %, Validation loss: 0.000337515
# [Epoch: 922][Batch:2][Training Accuracy: 99 %][Loss: 0.0822845]
#
# [Epoch: 922] Validation accuracy: 100 %, Validation loss: 0.000335048
# [Epoch: 923][Batch:2][Training Accuracy: 99 %][Loss: 0.01191]
#
# [Epoch: 923] Validation accuracy: 100 %, Validation loss: 0.000333463
# [Epoch: 924][Batch:2][Training Accuracy: 99 %][Loss: 0.0122105]
#
# [Epoch: 924] Validation accuracy: 100 %, Validation loss: 0.000331915
# [Epoch: 925][Batch:2][Training Accuracy: 99 %][Loss: 0.0727637]
#
# [Epoch: 925] Validation accuracy: 100 %, Validation loss: 0.000333169
# [Epoch: 926][Batch:2][Training Accuracy: 99 %][Loss: 0.0128744]
#
# [Epoch: 926] Validation accuracy: 100 %, Validation loss: 0.000336267
# [Epoch: 927][Batch:2][Training Accuracy: 98 %][Loss: 0.0136285]
#
# [Epoch: 927] Validation accuracy: 100 %, Validation loss: 0.000338289
# [Epoch: 928][Batch:2][Training Accuracy: 98 %][Loss: 0.0140755]
#
# [Epoch: 928] Validation accuracy: 100 %, Validation loss: 0.000339121
# [Epoch: 929][Batch:2][Training Accuracy: 98 %][Loss: 0.014249]
#
# [Epoch: 929] Validation accuracy: 100 %, Validation loss: 0.000338626
# [Epoch: 930][Batch:2][Training Accuracy: 100 %][Loss: 0.061067]
#
# [Epoch: 930] Validation accuracy: 100 %, Validation loss: 0.000340325
# [Epoch: 931][Batch:2][Training Accuracy: 98 %][Loss: 0.0146093]
#
# [Epoch: 931] Validation accuracy: 100 %, Validation loss: 0.00034272
# [Epoch: 932][Batch:2][Training Accuracy: 98 %][Loss: 0.0151702]
#
# [Epoch: 932] Validation accuracy: 100 %, Validation loss: 0.000343151
# [Epoch: 933][Batch:2][Training Accuracy: 98 %][Loss: 0.0154115]
#
# [Epoch: 933] Validation accuracy: 100 %, Validation loss: 0.000341939
# [Epoch: 934][Batch:2][Training Accuracy: 98 %][Loss: 0.0153826]
#
# [Epoch: 934] Validation accuracy: 100 %, Validation loss: 0.000339494
# [Epoch: 935][Batch:2][Training Accuracy: 98 %][Loss: 0.0151382]
#
# [Epoch: 935] Validation accuracy: 100 %, Validation loss: 0.000336167
# [Epoch: 936][Batch:2][Training Accuracy: 98 %][Loss: 0.0147317]
#
# [Epoch: 936] Validation accuracy: 100 %, Validation loss: 0.000332381
# [Epoch: 937][Batch:2][Training Accuracy: 100 %][Loss: 0.0603354]
#
# [Epoch: 937] Validation accuracy: 100 %, Validation loss: 0.000331255
# [Epoch: 938][Batch:2][Training Accuracy: 98 %][Loss: 0.0142627]
#
# [Epoch: 938] Validation accuracy: 100 %, Validation loss: 0.000331255
# [Epoch: 939][Batch:2][Training Accuracy: 98 %][Loss: 0.0145347]
#
# [Epoch: 939] Validation accuracy: 100 %, Validation loss: 0.000330129
# [Epoch: 940][Batch:2][Training Accuracy: 98 %][Loss: 0.0145586]
#
# [Epoch: 940] Validation accuracy: 100 %, Validation loss: 0.000327992
# [Epoch: 941][Batch:2][Training Accuracy: 98 %][Loss: 0.014379]
#
# [Epoch: 941] Validation accuracy: 100 %, Validation loss: 0.00032516
# [Epoch: 942][Batch:2][Training Accuracy: 100 %][Loss: 0.0597661]
#
# [Epoch: 942] Validation accuracy: 100 %, Validation loss: 0.00032468
# [Epoch: 943][Batch:2][Training Accuracy: 98 %][Loss: 0.0142361]
#
# [Epoch: 943] Validation accuracy: 100 %, Validation loss: 0.00032521
# [Epoch: 944][Batch:2][Training Accuracy: 98 %][Loss: 0.0146293]
#
# [Epoch: 944] Validation accuracy: 100 %, Validation loss: 0.0003245
# [Epoch: 945][Batch:2][Training Accuracy: 100 %][Loss: 0.0552276]
#
# [Epoch: 945] Validation accuracy: 100 %, Validation loss: 0.000325791
# [Epoch: 946][Batch:2][Training Accuracy: 98 %][Loss: 0.015307]
#
# [Epoch: 946] Validation accuracy: 100 %, Validation loss: 0.000327806
# [Epoch: 947][Batch:2][Training Accuracy: 98 %][Loss: 0.0159748]
#
# [Epoch: 947] Validation accuracy: 100 %, Validation loss: 0.000328157
# [Epoch: 948][Batch:2][Training Accuracy: 98 %][Loss: 0.0162892]
#
# [Epoch: 948] Validation accuracy: 100 %, Validation loss: 0.000327031
# [Epoch: 949][Batch:2][Training Accuracy: 98 %][Loss: 0.0162976]
#
# [Epoch: 949] Validation accuracy: 100 %, Validation loss: 0.000324651
# [Epoch: 950][Batch:2][Training Accuracy: 98 %][Loss: 0.0160574]
#
# [Epoch: 950] Validation accuracy: 100 %, Validation loss: 0.000321474
# [Epoch: 951][Batch:2][Training Accuracy: 98 %][Loss: 0.0156276]
#
# [Epoch: 951] Validation accuracy: 100 %, Validation loss: 0.000317774
# [Epoch: 952][Batch:2][Training Accuracy: 98 %][Loss: 0.0150632]
#
# [Epoch: 952] Validation accuracy: 100 %, Validation loss: 0.000313866
# [Epoch: 953][Batch:2][Training Accuracy: 98 %][Loss: 0.0144113]
#
# [Epoch: 953] Validation accuracy: 100 %, Validation loss: 0.000309987
# [Epoch: 954][Batch:2][Training Accuracy: 99 %][Loss: 0.0137107]
#
# [Epoch: 954] Validation accuracy: 100 %, Validation loss: 0.000306216
# [Epoch: 955][Batch:2][Training Accuracy: 99 %][Loss: 0.0129916]
#
# [Epoch: 955] Validation accuracy: 100 %, Validation loss: 0.000302767
# [Epoch: 956][Batch:2][Training Accuracy: 99 %][Loss: 0.0122768]
#
# [Epoch: 956] Validation accuracy: 100 %, Validation loss: 0.000299554
# [Epoch: 957][Batch:2][Training Accuracy: 99 %][Loss: 0.0730974]
#
# [Epoch: 957] Validation accuracy: 100 %, Validation loss: 0.000298228
# [Epoch: 958][Batch:2][Training Accuracy: 99 %][Loss: 0.0115149]
#
# [Epoch: 958] Validation accuracy: 100 %, Validation loss: 0.000297797
# [Epoch: 959][Batch:2][Training Accuracy: 99 %][Loss: 0.0117621]
#
# [Epoch: 959] Validation accuracy: 100 %, Validation loss: 0.000296923
# [Epoch: 960][Batch:2][Training Accuracy: 99 %][Loss: 0.0118293]
#
# [Epoch: 960] Validation accuracy: 100 %, Validation loss: 0.000295453
# [Epoch: 961][Batch:2][Training Accuracy: 99 %][Loss: 0.0117436]
#
# [Epoch: 961] Validation accuracy: 100 %, Validation loss: 0.000293588
# [Epoch: 962][Batch:2][Training Accuracy: 99 %][Loss: 0.0115349]
#
# [Epoch: 962] Validation accuracy: 100 %, Validation loss: 0.000291595
# [Epoch: 963][Batch:2][Training Accuracy: 99 %][Loss: 0.0112324]
#
# [Epoch: 963] Validation accuracy: 100 %, Validation loss: 0.000289415
# [Epoch: 964][Batch:2][Training Accuracy: 99 %][Loss: 0.0108631]
#
# [Epoch: 964] Validation accuracy: 100 %, Validation loss: 0.000287099
# [Epoch: 965][Batch:2][Training Accuracy: 99 %][Loss: 0.0104506]
#
# [Epoch: 965] Validation accuracy: 100 %, Validation loss: 0.000284862
# [Epoch: 966][Batch:2][Training Accuracy: 99 %][Loss: 0.0100147]
#
# [Epoch: 966] Validation accuracy: 100 %, Validation loss: 0.000282646
# [Epoch: 967][Batch:2][Training Accuracy: 99 %][Loss: 0.00957111]
#
# [Epoch: 967] Validation accuracy: 100 %, Validation loss: 0.000280538
# [Epoch: 968][Batch:2][Training Accuracy: 99 %][Loss: 0.090962]
#
# [Epoch: 968] Validation accuracy: 100 %, Validation loss: 0.000279692
# [Epoch: 969][Batch:2][Training Accuracy: 99 %][Loss: 0.00925191]
#
# [Epoch: 969] Validation accuracy: 100 %, Validation loss: 0.000279721
# [Epoch: 970][Batch:2][Training Accuracy: 99 %][Loss: 0.00970185]
#
# [Epoch: 970] Validation accuracy: 100 %, Validation loss: 0.000279398
# [Epoch: 971][Batch:2][Training Accuracy: 99 %][Loss: 0.0099822]
#
# [Epoch: 971] Validation accuracy: 100 %, Validation loss: 0.000278731
# [Epoch: 972][Batch:2][Training Accuracy: 99 %][Loss: 0.010106]
#
# [Epoch: 972] Validation accuracy: 100 %, Validation loss: 0.000277641
# [Epoch: 973][Batch:2][Training Accuracy: 99 %][Loss: 0.0100939]
#
# [Epoch: 973] Validation accuracy: 100 %, Validation loss: 0.000276336
# [Epoch: 974][Batch:2][Training Accuracy: 99 %][Loss: 0.00997046]
#
# [Epoch: 974] Validation accuracy: 100 %, Validation loss: 0.000274802
# [Epoch: 975][Batch:2][Training Accuracy: 99 %][Loss: 0.0097605]
#
# [Epoch: 975] Validation accuracy: 100 %, Validation loss: 0.000273009
# [Epoch: 976][Batch:2][Training Accuracy: 99 %][Loss: 0.0850931]
#
# [Epoch: 976] Validation accuracy: 100 %, Validation loss: 0.00027278
# [Epoch: 977][Batch:2][Training Accuracy: 99 %][Loss: 0.00974443]
#
# [Epoch: 977] Validation accuracy: 100 %, Validation loss: 0.000273662
# [Epoch: 978][Batch:2][Training Accuracy: 99 %][Loss: 0.010302]
#
# [Epoch: 978] Validation accuracy: 100 %, Validation loss: 0.000274013
# [Epoch: 979][Batch:2][Training Accuracy: 99 %][Loss: 0.0106525]
#
# [Epoch: 979] Validation accuracy: 100 %, Validation loss: 0.00027374
# [Epoch: 980][Batch:2][Training Accuracy: 99 %][Loss: 0.0108128]
#
# [Epoch: 980] Validation accuracy: 100 %, Validation loss: 0.000272959
# [Epoch: 981][Batch:2][Training Accuracy: 99 %][Loss: 0.0108094]
#
# [Epoch: 981] Validation accuracy: 100 %, Validation loss: 0.000271697
# [Epoch: 982][Batch:2][Training Accuracy: 99 %][Loss: 0.0106729]
#
# [Epoch: 982] Validation accuracy: 100 %, Validation loss: 0.000270119
# [Epoch: 983][Batch:2][Training Accuracy: 99 %][Loss: 0.0104341]
#
# [Epoch: 983] Validation accuracy: 100 %, Validation loss: 0.000268355
# [Epoch: 984][Batch:2][Training Accuracy: 99 %][Loss: 0.0101216]
#
# [Epoch: 984] Validation accuracy: 100 %, Validation loss: 0.000266477
# [Epoch: 985][Batch:2][Training Accuracy: 99 %][Loss: 0.00976009]
#
# [Epoch: 985] Validation accuracy: 100 %, Validation loss: 0.000264648
# [Epoch: 986][Batch:2][Training Accuracy: 99 %][Loss: 0.00937024]
#
# [Epoch: 986] Validation accuracy: 100 %, Validation loss: 0.000262777
# [Epoch: 987][Batch:2][Training Accuracy: 99 %][Loss: 0.00896826]
#
# [Epoch: 987] Validation accuracy: 100 %, Validation loss: 0.000261006
# [Epoch: 988][Batch:2][Training Accuracy: 99 %][Loss: 0.00856647]
#
# [Epoch: 988] Validation accuracy: 100 %, Validation loss: 0.000259328
# [Epoch: 989][Batch:2][Training Accuracy: 99 %][Loss: 0.00817361]
#
# [Epoch: 989] Validation accuracy: 100 %, Validation loss: 0.000257808
# [Epoch: 990][Batch:2][Training Accuracy: 99 %][Loss: 0.00779574]
#
# [Epoch: 990] Validation accuracy: 100 %, Validation loss: 0.000256338
# [Epoch: 991][Batch:2][Training Accuracy: 99 %][Loss: 0.00743639]
#
# [Epoch: 991] Validation accuracy: 100 %, Validation loss: 0.000255054
# [Epoch: 992][Batch:2][Training Accuracy: 99 %][Loss: 0.00709765]
#
# [Epoch: 992] Validation accuracy: 100 %, Validation loss: 0.000253857
# [Epoch: 993][Batch:2][Training Accuracy: 99 %][Loss: 0.00678017]
#
# [Epoch: 993] Validation accuracy: 100 %, Validation loss: 0.000252659
# [Epoch: 994][Batch:2][Training Accuracy: 99 %][Loss: 0.00648367]
#
# [Epoch: 994] Validation accuracy: 100 %, Validation loss: 0.000251605
# [Epoch: 995][Batch:2][Training Accuracy: 99 %][Loss: 0.00620752]
#
# [Epoch: 995] Validation accuracy: 100 %, Validation loss: 0.000250608
# [Epoch: 996][Batch:2][Training Accuracy: 99 %][Loss: 0.00595057]
#
# [Epoch: 996] Validation accuracy: 100 %, Validation loss: 0.00024964
# [Epoch: 997][Batch:2][Training Accuracy: 99 %][Loss: 0.00571159]
#
# [Epoch: 997] Validation accuracy: 100 %, Validation loss: 0.000248744
# [Epoch: 998][Batch:2][Training Accuracy: 99 %][Loss: 0.00548915]
#
# [Epoch: 998] Validation accuracy: 100 %, Validation loss: 0.000247862
# [Epoch: 999][Batch:2][Training Accuracy: 99 %][Loss: 0.00528198]
#
# [Epoch: 999] Validation accuracy: 100 %, Validation loss: 0.000247095

# %%
torch.save(model.module.state_dict(), "/home/alexandru/html/model/html/Test")

# %%
vocabularySize = len(trainData.vocabulary['letter2id'])+1
modelOne =ModelOne(vocabulary_size=vocabularySize,
             hidden_size=100,
             embedding_size=50,
             num_layers=3,
             rnn_dropout=0.0,
             dropout=0,
             num_directions=2).to(device)
modelOne.load_state_dict(torch.load("/home/alexandru/html/model/html/Test"))

# %%
def sample_sentence():
    words = list()
    count = 0
    modelOne.eval()
    with torch.no_grad():
        # Setup initial input state, and input word (we use "the").
        previousWord = torch.LongTensor(1, 1).fill_(trainData.vocabulary['letter2id']['[START]'])
        hidden =  Variable(torch.zeros(6, 1, 100).to(device))


        while True:
            # Predict the next word based on the previous hidden state and previous word.
            inputWord = torch.autograd.Variable(previousWord.to(device))
            
            #print("Prediction: ")
            
            predictions, newHidden = modelOne(inputWord, hidden)
            
            hidden = newHidden
            
            #print("After prediction")
            
            pred = torch.nn.functional.softmax(predictions.squeeze()).data.cpu().numpy().astype('float64')
            
            pred = pred/np.sum(pred)
            
            #print("After normalization")
            
            nextWordId = np.random.multinomial(1, pred, 1).argmax()

            #print("After nextWordId computation")
            
            if nextWordId == 0:
                continue
            
            #print("After nextWordId zero value check")

            words.append(trainData.vocabulary['id2letter'][nextWordId])
            # Setup the inputs for the next round.
            previousWord.fill_(nextWordId)


            # Keep adding words until the [END] token is generated.
            if nextWordId == trainData.vocabulary['letter2id']['[END]']:
                break

            if count>20000:
                break
            count += 1
        words.insert(0, '[START]')


        return words

# %%
def generate_sample_html():
    html = sample_sentence()
    print(len(html))
    print("".join(html))

# %%
generate_sample_html()
# Out:
# 57
# [START]..<a<a<a<a<aa<ttp11111b11111b11111111b11b1bbbb<btttn111[END]
# /home/alexandru/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
